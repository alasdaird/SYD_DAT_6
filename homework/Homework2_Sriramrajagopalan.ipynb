# %% [markdown]
# # SYD DAT 6 Homework 2 - Visualisation, Regression and Classification
#
# ## Homework - Due Monday 14th November 2016
#
# All responses should be written in markdown or code in this document.
#
# ----
#
# #### Setup
# * Signup for an AWS account
#
# #### Python Programming Skills
# * Complete all the labs
# * Experiment with tutorials 1 & 2 from https://github.com/fonnesbeck/statistical-analysis-python-tutorial
# * Referring to the prior labs perform some simple analysis of the titanic.csv dataset using python
#     * Load the data set titanic.csv
#     * Produce 1 simple visualisation with matplotlib/seaborn/pandas visualisation libraries to show the distribution of ages
#     * How many male 3rd class passengers survived and how many did not survive
#     * How many female 1st class passengers survived and how many did not survive
#     * Produce a table grouped by class that shows:
#         * Percent survived
#         * Average fare
#
#
# #### Machine Learning Theory
# * Reading that was required during the course from Introduction to Statistical Learning
#     * Chapter 3 - Linear Regression
#     * Chapter 4 - 4.1, 4.2, 4.3  - Classification
#     * Chapter 5 - 5.1 - Cross Validation
#     * Chapter 6 - 6.1, 6.2, 6.3 - Dimensionality
# * Complete all the labs
# * Describe what technique you might apply to predict whether a person has AIDs. What could you do to reduce the probability that the solution mistakenly predicts that a person does not have AIDs, when in fact they do?
#
#
# #### Visualisation
# * Drawing from Keegan from Optus' talk, your own experience or any other source, describe what you believe are the 3 most important considerations in producing a visualisation.
# * Name 3 types of plots you can think of to address each of the following situations:
#     * Show the distribution of a single variable
#     * Show a relationship between two variables
#     * Compare two or more variables
#
#
# #### Communication
# * Imagine you are trying to explain to someone what Linear Regression is - but they have no programming/maths experience? How would you explain the overall process, what R-Squared means and how to interpret the coefficients?
# * Read the paper [Useful things to know about machine learning]( https://homes.cs.washington.edu/~pedrod/papers/cacm12.pdf).
#     * What have we covered so far from this paper?
#     * Explain sections 6-13 in your own words
#
#
# #### Course Project
# * Set up a new github repository for your project.
#     * If there is any sensitive data or material in your project, make it a private repository - but check with us first. For most of you this will not be necessary. Generally you would exclude data from git tracking - this can be achieved with the .gitignore file. Don't worry about excluding files from git if you are using smaller, public datasets.
#     * Once you have established the github repository for your project, share the URL for the repository with Alasdair and Louis via Slack. If it is a private repository you will additionally need to give Alasdair and Louis permissions.
# * Load the data you have gathered for your project into Python and run some summary statistics over the data. Are there any interesting features of the data that jump out? (Include the code)
# * Draft/Sketch on paper (or wireframe) some data visualisations that would be useful for you to explore your data set
# * Are there any regression or clustering techniques you could use in your project? Write them down (with the corresponding scikit learn function) and what you think you would get out of it.
#
#
# **Instructions: copy this file and append your name in the filename, e.g. Homework2_alasdaird.ipynb.
# Then commit this in your local repository, push it to your github account and create a pull request so I can see your work. Remeber if you get stuck to look at the slides going over Fork, Clone, Commit, Push and Pull request.**

# %% [markdown]
# #Communication
# #Imagine you are trying to explain to someone what Linear Regression is - but they have no programming/maths experience? How would you explain the overall process, what a p-value means and what R-Squared means?
# #Linear regression aims to mathematically identify and subsequently describe a relationship between two sets of data. Once the relationship has been identified and quantified, we can predict changes to one set of data based on movements in the other set of data.
#
# #The overall process involves
#     -obtaining the data sets of interest.
#     -identifying which data you would like to explain/predict (Call this 'A') and which data you would like to
#     -utlise for the explanation/prediciton (call this B, which can contain multiple elements)
#     -use mathematical techniques applied to the data set on hand to form a mathematical relationship between B and
#     -the element(s) in B
#     -use some simple statistical tests to determine the quality of your model, how strong the relationship between
#     -elements in B are with A.
# #P-values and R^2 are two tests used to describe the strength of the relationship between B & A.
#     -P-Values use statistical tests to determine a value 'p' for the elements in B used to describe A. The value p
#      describes the likelihood of seeing a substantial association between the elements of A & B if we run the tests
#      numerous times. A large value for p indicates there is a large likelihood, a small value indicates the
#      relationship we deduced was due to chance.
#     -R^2 is a metric which describes the explanatory power of your model with elements of B to describe A. It
#     indicates the proportion of B which can be explained by A. A high value for R^s indicates a strong model.
# #What have we covered so far from this paper?
# #Explain sections 6-13 in your own words
# #items covered mentioned in the paper are
#     -Cross validation
#     -Statistical significance testing
#     -bias/variance trade off
#     -overfitting
#     -regularisation
#     -fixed size representation learners (linear regression)
# #Explain sections 6-13 in your own words
# #curse of dimensionality, in higher dimensions, beyond the 3rd, most data is is distributed in a shell around the
#  mean.
# #in higher dimensions, many classifiers in a model will not add much significance to the model and cloud the
#  signals provided by  those significant classifiers.
# #Adding many classifers to a model can work against the model as per the "curse of dimentionality".
# #However this can be negated by the "blessing of non-uniformity" where there is clustering of data around lower
# dimensions.
#
# #theoretical guarantees in machine learning should not be used for decision making, but as a source of
# understanding and developing algorithmns.
#
# #raw data is not in a format that can be read directly. A process of obtaining, cleaning, pre processing
# & identifying features is what feature engineering involves.
#
# #as a rule of thumb, in variable learners like decision trees, the more data you have, the better the model
# will be. However a tradeoff between data & processing time may limit the benefits of gathering more data.
# #Linear classifiers such as linear regression benefit less and less as more data is fed into the model.
#
# #Bagging is a technique which generates random sets of training data, obtains classifers, then combines the
# results over multiple re-samples. Model ensembles have proven to be complex models which combine leaners from
# many models to form one model. These have proven to be very successful as per the Netflix prize competition.
#
# #while you can extract causal information from learning algorithms, only limited information can be obtained.
# learning models are used as a guide for action.

# %% [markdown]
# #Machine Learning
#
# #Describe 3 ways we can select what features to use in a model
#
# #Subset Method: progressively add features to a model, and note the added explanatory power of the feature.
# #Once all features have been added, then only select those features which added significant explanatory power to the model
# #regularisation (Lasso & Ridge): These are similar to OLS, but integrate a penalty function which contrains the size of
# #the coefficients in the model. the higher the penalty paramater (lambda), the greater the shrinkage effect is on the model coefficients
# #this allows us to see which features have the most significance. In the case of Lasso, paramters can be shrunken to zero, while in
# #ridge regression the paramters are taken very close to zero, but don't become exactly zero. In both methods, Theres a significant reduction
# #in the variance with only a slight increase in the bias.
# #Dimention Reduction (PCA): Involves, transforming the data into components which explain most of the variance of the data set
# #and then applying these components as c predictors in our linear regression model. They key premise here is that a small number
# #of principal components are enough to explain the variance in the data

# %% [markdown]
# #Visualisation
#
# #Visualisation
# #Drawing from Keegan from Optus' talk, your own experience or any other source, describe what you believe are the 3 most important considerations in producing a visualisation.
# #Name 3 types of plots you can think of to address each of the following situations:
# #Show the distribution of a single variable
# #Show a relationship between two variables
# #Compare two or more variables
#
#
# #Drawing from Keegan from Optus' talk, your own experience or any other source,
# #describe what you believe are the 3 most important considerations in producing a visualisation.
#
#     #The 3 most important considerations in visualisation is
#         1.Know the audience you are presenting the visualisation analysis to.
#         2.When in doubt keep it simple.
#         3.Ensure you are using the right type of visualisation for the story you are trying to tell.
#
#
# #Name 3 types of plots you can think of to address each of the following situations:
#
# #Show the distribution of a single variable
#     #line graph
#     #histogram
#     #bar graph
# #Show a relationship between two variables
#     #scatter plot
#     #line graph (lines for each variable ie. want to show inverse relationships etc)
#     #Box Plot
#
# #Compare two or more variables
#     #pie chart
#     #Stacked Column Graph
#     #Line chart with a line for each variable

# %% [markdown]
# Machine Learning Theory
#
# Reading that was required during the course from Introduction to Statistical Learning
# Chapter 3 - Linear Regression
# Chapter 4 - 4.1, 4.2, 4.3 - Classification
# Chapter 5 - 5.1 - Cross Validation
# Chapter 6 - 6.1, 6.2, 6.3 - Dimensionality
# Complete all the labs
#
# #Describe what technique you might apply to predict whether a person has AIDs. What could you do to reduce the  probability that the solution mistakenly predicts that a person does not have AIDs, when in fact they do?
#
# The technique which should be used for this problem is a logistic regression which would indicate the probability that a person has aids given a number of factors which have been identified in the regression process as having strong signals in explaining the dependendent variable (whether somone has aids or not)
#
# In the instance where the solution mistakenly predicts that a person does not have aids when they do is a 'false negative'. This may suggest that our model may lack enough signals to correctly predict somone has aids. By adding more variables, we can increase the strength of the signals to predict someone has aids.
#
# Also, the variables in our model may not have strong explanatory power. We can alter the variables we choose for the regression through regularisation techniques and dimension reduction to identify and use those variables that have a strong relationship & provide strong signals with respect to the independent variable.

# %%
#Referring to the prior labs perform some simple analysis of the titanic.csv dataset using python

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


#Load the data set titanic.csv

titanic = pd.read_csv('titanic.csv', index_col='PassengerId')
titanic.head()

#Produce 1 simple visualisation with matplotlib/seaborn/pandas visualisation libraries to show the distribution of ages

titanic.Age.hist(bins=15)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

#How many male 3rd class passengers survived and how many did not survive
#not survived (Survived ==0)
print len(titanic[(titanic['Pclass']==3) & (titanic['Sex']== 'male') & (titanic['Survived']== 0)])
#survived (Survived ==1)
print len(titanic[(titanic['Pclass']==3) & (titanic['Sex']== 'male') & (titanic['Survived']== 1)])



#How many female 1st class passengers survived and how many did not survive
#not survived (Survived ==0)
print len(titanic[(titanic['Pclass']==1) & (titanic['Sex']== 'female') & (titanic['Survived']== 0)])
#survived (Survived ==1)
print len(titanic[(titanic['Pclass']==1) & (titanic['Sex']== 'female') & (titanic['Survived']== 1)])




#Produce a table grouped by class that shows:

#Percent survived
x = titanic.groupby(['Pclass','Survived']).count()
x = pd.DataFrame(x)
x = x.ix[:,:1]
x1 = x.groupby(level=0).apply(lambda y: 100*y/float(y.sum()))

x1 = pd.DataFrame(x1)
x1

#Average fare
avgfare = titanic.groupby(['Pclass'])['Fare'].mean()
avgfare = pd.DataFrame(avgfare)
avgfare
# Out:
# 300
# 47
# 3
# 91
#              Fare
# Pclass
# 1       84.154687
# 2       20.662183
# 3       13.675550

# %%
#Project Data

import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)

xl = pd.ExcelFile("Project_Data.xlsx")
xl.sheet_names
df = xl.parse("Sheet1")

#first look at the data
df.head()

# examine to see if there are any null rows
df.isnull().sum()

#there are rows with null data, let us remove these rows
df = df.dropna()

# we have 547 rows of data left, enough for the regression. the dataframe has been cleaned.
df.count()

#run summary statistics over the data
df.describe()
    #looks like the standard deviations and quartile levels for the dependent variables "ASX Lit Share", "ASX Dark Share", "ASX On Market", "ASX Continuous Share"
    #are all very tight, the independent variables do not vary my large orders of magnitiude
    
    #Our independent variables are all of differrent measures including $'s, %'s, dummy variables & plain incremental units ('number of customer meetings')
    #Given the main purpose is to deduce relationships with the independent variables (with prediction being secondary) , we will require some normalisation techniques to standardise the dependent variables

#In the next sections of code, we will provide a correllation analysis with some of the key independent variables

df.columns
# Out:
# Index([u'Date', u'Date.1', u'ASX Lit Share', u'ASX Dark Share',
#        u'ASX On Market', u'ASX Continous Share', u'ASX Lit', u'Chi-X Lit',
#        u'ASX Centre Point', u'Chi-X Dark', u'Reported to ASX',
#        u'Reported to Chi-X', u'Market', u'Lit + Dark', u'Lit', u'Reports',
#        u'CP Share', u'Row', u'Lit Trading - Vanilla', u'Trade Registration',
#        u'Block Discovery', u'Undisclosed', u'CentrePoint', u'Icebergs',
#        u'Pref', u'UCP', u'CXA Market', u'Specials', u'NBBO Trade Report',
#        u'Portfolio Specials', u'Late Trades', u'Broker Pref',
#        u'20-Day Realised SPI Vol', u'MOC', u'Spread Differrential',
#        u'NBBO Trade Report.1', u'%Sweep of Lit', u'Index Rebalance',
#        u'ASX Lit Share (20 MA)', u'ASX Dark Share (20 MA)', u'ASX On Market.1',
#        u'ASX Continous Share (20 MA)', u'Number of Customer Meetings',
#        u'Average Meetings'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

#My initial approach as of now is to create 4 separate regressions using the following columns as dependent variables
    #ASX Lit Share, ASX Dark Share, ASX On Market, ASX Continous

#Taking ASX On Market Share as an example, lets to a simple correllation analysis with some key independent variables

#u'20-Day Realised SPI Vol', u'MOC', u'Spread Differrential',
#       u'NBBO Trade Report.1', u'%Sweep of Lit', u'Index Rebalance',
#       u'ASX Lit Share (20 MA)', u'ASX Dark Share (20 MA)', u'ASX On Market.1',
#       u'ASX Continous Share (20 MA)', u'Number of Customer Meetings',
#       u'Average Meetings'

dfSub = df[['ASX On Market', '20-Day Realised SPI Vol','Spread Differrential', '%Sweep of Lit', 'Index Rebalance', 'ASX Lit Share (20 MA)', 'ASX Dark Share (20 MA)','Number of Customer Meetings', 'Average Meetings']]

dfSub.corr()

#correllations between the dependent variables donot appear to be very very strong, max correllation is -0.5 % sweep of lit and ASX Lit Share, 20-day Relaised SPI Vol and ASX Dark Market Share

#correllations seem to vary quite a bit, let us see how it looks graphically

#Plot the data
pd.scatter_matrix(dfSub, figsize=(15,15))
plt.show()

#initial look at the data indicates the following-

    #there is a strong correllation between the lit share 20 day MA and the on market share
    #A negative relationship between Lit as % of lit market and on market share (surprising!)
    #On market share increases as the spread differrential increases
    
    #Amongst the independent variables 
        #the SPI volatility and Dark market share are negatively correllated
        # %sweep of lit and the spread differrential seem to have a positive relationship
        #As the spread differrential becomes increasingly negative, the lit market share 20 day MA increases
        
#Another graph we could utilise is the
    #density histograms to analyse the distribution (extremes) of the independent and dependent variables
    

#Looking ahead, clustering will not be relevant to this problem as it is a pure linear regression/Decision Tree problem
#we'll need to normalise the variables in order to determine relationships

#the following libraries will be required
    #Linear Regression - import statsmodels.formula.api as smf
    #Linear Regression for CV/Lasso/Ridge from sklearn.cross_validation import train_test_split
    #Decision Trees - from sklearn import tree
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-5a9c2a1bc1e5> in <module>()
#      38     #density histograms to analyse the independent and dependent variables
#      39
# ---> 40 dfSub.ASX_On_Market.plot(kind='density', xlim=(0,500))
#      41 plt.xlabel('Beer Servings')
#
# C:\Users\Madhu\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'ASX_On_Market'
