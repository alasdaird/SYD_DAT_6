# %% [markdown]
# # SYD DAT 6 Lab 1 - Git and Markdown
#
# ## Homework:
#
# #### Setup
# * Resolve any installation issues before next class.
# * Make sure you have a github profile and created a repo called "SYD_DAT_6"
# * Clone the class repo (this one!)
# * Review this [code](../labs/Week 1/00_python_refresher.py) for a recap of some Python basics.
#
# #### Communication
# * Read [Analyzing the Analyzers](http://cdn.oreillystatic.com/oreilly/radarreport/0636920029014/Analyzing_the_Analyzers.pdf) for a useful look at the different types of data scientists. Write down 5 key points you took away from the article
# * Read about some [Markdown Techniques](http://daringfireball.net/projects/markdown/syntax)
# * Write a summary of 2 chapters of [The Data Science Handbook](http://www.thedatasciencehandbook.com/) in Markdown and submit a pull request in the Lab Directory
#
# #### Programming
# * Complete the lab from class and the additional Exercise below
#
# #### Course Project
# * Come up with 5 different ideas for your course project. For each one list:
#   * Overview of your idea
#   * What data you will use
#   * What the outcome is that you are trying to achieve
#   * Any ideas of modelling techniques it may involve
#
# **Instructions: copy this file and append your name in the filename, e.g. Homework1_alasdair_douglas.ipynb.
# Then commit this in your local repository, push it to your github account and create a pull request so I can see your work. Remeber if you get stuck to look at the slides going over Fork, Clone, Commit, Push and Pull request.**

# %% [markdown]
# #Key Points for Final Assignment:
#
#     1. I would like to pull data from my companies Contact Center. They receive calls from
#     Investors and advisers. They need to meet GOS (grad of service). I like to find out if there is a certian
#     time of the year where they are not able to meet service level agreement.
#     The data would be pulled from Salesforce and data warehouse. I will be looking at abandonment times, calls handled. etc.
#
#     Outcome: to see if we need to hire more people at certain times of the year.
#     Modelling Techniques: Not sure yet.
#
#     2. The marketing team is launching a new website. They are sending out surveyes to selected Advisers to get their feedback.
#     Outcome: I would like to use data from Salesforce to see, how effective are these email surveys. What it tells of the website
#         if emails is the best way to get feedback.
#
# 3. Marketing sends out email campaign, inviting advisers to a seminar or workshop. I want to see how many advisers ae clicking
#     on the invitation and if these invites are encouraging advisers to write up more Annuities..
#
# Outcome: see how much revenue these campaigns are generating income for the business.
#         Data: collected from Salesfroce
#             Modeling: not sure.

# %% [markdown]
# Read Analyzing the Analyzers for a useful look at the different types of data scientists. Write down 5 key points you took away from the article
#
# 1. misunderstandings about the roles of data scientists.
# 2. excessive hype leads people to expect miracles, and miracle-workers.
# 3.companies failing to communicate the roles responsibilities. Leading to a mis match beteen expectations and applicants
# 4. There are different varity of data scientist
# 5. Having a data scientist embeded in a team will allow them to focus on the skills needed for that team. However if you rotate them between teams, it will allow them to gain different skills.

# %% [markdown]
# ## Exercise Four - Movie Lens Data

# %%
# for each occupation in 'users', count the number of occurrences

# for each occupation, calculate the mean age

# for each occupation, calculate the minimum and maximum ages

# for each combination of occupation and gender, calculate the mean age

# randomly sample a DataFrame

# detect duplicate users

# %%
# for each occupation in 'users', count the number of occurrences

# %%
import pandas as pd

# %%
pd.read_table('u.user', header=None)
# Out:
#                                 0
# 0         1|24|M|technician|85711
# 1              2|53|F|other|94043
# 2             3|23|M|writer|32067
# 3         4|24|M|technician|43537
# 4              5|33|F|other|15213
# 5          6|42|M|executive|98101
# 6      7|57|M|administrator|91344
# 7      8|36|M|administrator|05201
# 8            9|29|M|student|01002
# 9            10|53|M|lawyer|90703
# 10            11|39|F|other|30329
# 11            12|28|F|other|06405
# 12         13|47|M|educator|29206
# 13        14|45|M|scientist|55106
# 14         15|49|F|educator|97301
# 15    16|21|M|entertainment|10309
# 16       17|30|M|programmer|06355
# 17            18|35|F|other|37212
# 18        19|40|M|librarian|02138
# 19        20|42|F|homemaker|95660
# 20           21|26|M|writer|30068
# 21           22|25|M|writer|40206
# 22           23|30|F|artist|48197
# 23           24|21|F|artist|94533
# 24         25|39|M|engineer|55107
# 25         26|49|M|engineer|21044
# ...

# %%
user_cols = ['user_id', 'age', 'gender', 'occupation', 'zip_code']
users = pd.read_table('u.user', sep='|', header=None, names=user_cols, index_col='user_id', dtype={'zip_code':str})

# %%
users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# 6         42      M      executive    98101
# 7         57      M  administrator    91344
# 8         36      M  administrator    05201
# 9         29      M        student    01002
# 10        53      M         lawyer    90703
# 11        39      F          other    30329
# 12        28      F          other    06405
# 13        47      M       educator    29206
# 14        45      M      scientist    55106
# 15        49      F       educator    97301
# 16        21      M  entertainment    10309
# 17        30      M     programmer    06355
# 18        35      F          other    37212
# 19        40      M      librarian    02138
# 20        42      F      homemaker    95660
# ...

# %%
users.occupation.value_counts()
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# salesman          12
# lawyer            12
# none               9
# homemaker          7
# doctor             7
# Name: occupation, dtype: int64

# %%
# for each occupation, calculate the mean age

# %%
users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
for each occupation, calculate the minimum and maximum ages

# %%
users.groupby("occupation").age.min()
# Out:
# occupation
# administrator    21
# artist           19
# doctor           28
# educator         23
# engineer         22
# entertainment    15
# executive        22
# healthcare       22
# homemaker        20
# lawyer           21
# librarian        23
# marketing        24
# none             11
# other            13
# programmer       20
# retired          51
# salesman         18
# scientist        23
# student           7
# technician       21
# writer           18
# Name: age, dtype: int64

# %%
users.groupby("occupation").age.max()
# Out:
# occupation
# administrator    70
# artist           48
# doctor           64
# educator         63
# engineer         70
# entertainment    50
# executive        69
# healthcare       62
# homemaker        50
# lawyer           53
# librarian        69
# marketing        55
# none             55
# other            64
# programmer       63
# retired          73
# salesman         66
# scientist        55
# student          42
# technician       55
# writer           60
# Name: age, dtype: int64

# %%
for each combination of occupation and gender, calculate the mean age

# %%
users.groupby(['occupation', 'gender']).age.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-805fe8d7248f> in <module>()
# ----> 1 users.groupby(['occupation', 'gender']).age.mean()
#
# NameError: name 'users' is not defined

# %%
#randomly sample a DataFrame

# %%
users.sample(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cdbb62ffd26d> in <module>()
# ----> 1 users.sample(20)
#
# NameError: name 'users' is not defined

# %%
DataFrame.sample(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-915eeb32174b> in <module>()
# ----> 1 DataFrame.sample(20)
#
# NameError: name 'DataFrame' is not defined

# %%
# detect duplicate users

# %%
users.duplicated()
# Out:
# user_id
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
#        ...
# 914    False
# 915    False
# 916    False
# 917    False
# 918    False
# 919    False
# 920    False
# 921    False
# 922    False
# 923    False
# 924    False
# 925    False
# 926    False
# 927    False
# 928    False
# 929    False
# 930    False
# 931    False
# 932    False
# 933    False
# 934    False
# 935    False
# 936    False
# 937    False
# 938    False
# 939    False
# 940    False
# 941    False
# 942    False
# 943    False
# dtype: bool
