# %% [markdown]
# # Recommendation Engines
#
# ## Monday 20 November 2016
#
# 1. Load and summarise data
# 2. Calculate the Jaccard Similarity
# 3. Recommender (User Similarity)
# 4. Recommender (Item Similarity)

# %%
# 1. Load and Summarise the data
import pandas as pd

#read in brands data - fill in
user_brands = pd.read_csv('user_brand.csv')

#look at count of stores
user_brands.Store.value_counts()

# Series of user IDs, note the duplicates
user_ids = user_brands.ID

user_ids
#user_brands.head()
# Out:
# 0        80002
# 1        80002
# 2        80010
# 3        80010
# 4        80010
# 5        80010
# 6        80010
# 7        80010
# 8        80010
# 9        80010
# 10       80010
# 11       80010
# 12       80011
# 13       80011
# 14       80011
# 15       80011
# 16       80011
# 17       80011
# 18       80011
# 19       80011
# 20       80011
# 21       80011
# 22       80011
# 23       80011
# 24       80011
# 25       80011
# 26       80015
# 27       80015
# 28       80015
# 29       80015
#          ...
# 23774    91924
# 23775    91927
# 23776    91927
# 23777    91931
# 23778    91931
# 23779    91931
# 23780    91931
# 23781    91943
# 23782    91943
# 23783    91943
# 23784    91944
# 23785    91944
# 23786    91944
# 23787    91944
# 23788    91944
# 23789    91944
# 23790    91944
# 23791    91944
# 23792    91944
# 23793    91944
# 23794    91946
# 23795    91946
# 23796    91946
# 23797    91946
# 23798    91955
# 23799    91957
# 23800    91957
# 23801    91957
# 23802    91957
# 23803    91957
# Name: ID, dtype: int64

# %%
# groupby ID to see what each user likes
user_brands.groupby('ID').Store.value_counts()
# Out:
# ID     Store
# 80002  Home Depot              1
#        Target                  1
# 80010  Container Store         1
#        Converse                1
#        Cuisinart               1
#        DKNY                    1
#        Express                 1
#        Kohl's                  1
#        Levi's                  1
#        Nordstrom               1
#        Old Navy                1
#        Puma                    1
# 80011  BCBGMAXAZRIA            1
#        Banana Republic         1
#        Calvin Klein            1
#        Crate & Barrel          1
#        Diesel                  1
#        French Connection       1
#        Gap                     1
#        Guess                   1
#        Kenneth Cole            1
#        Nine West               1
#        Nordstrom               1
#        Restoration Hardware    1
#        Steve Madden            1
#        Target                  1
# 80015  Banana Republic         1
#        Gap                     1
#        Home Depot              1
#        Target                  1
#                               ..
# 91924  Nordstrom               1
# 91927  Banana Republic         1
#        Calvin Klein            1
# 91931  Container Store         1
#        Crocs                   1
#        Home Depot              1
#        KitchenAid              1
# 91943  Kohl's                  1
#        Life is good            1
#        Old Navy                1
# 91944  Crate & Barrel          1
#        Express                 1
#        French Connection       1
#        Guess                   1
#        Home Depot              1
#        Kohl's                  1
#        Lands' End              1
#        Nine West               1
#        Old Navy                1
#        Target                  1
# 91946  Levi's                  1
#        Nordstrom               1
#        Old Navy                1
#        Target                  1
# 91955  Serena and Lily         1
# 91957  BCBGMAXAZRIA            1
#        Container Store         1
#        Express                 1
#        Old Navy                1
#        Target                  1
# Name: Store, dtype: int64

# %%
# turns my data frame into a dictionary
# where the key is a user ID, and the value is a 
# list of stores that the user "likes"
brandsfor = {str(k): list(v) for k,v in user_brands.groupby("ID")["Store"]}
#brandsfor
# Out:
# {'87026': ['Banana Republic'],
#  '86932': ["Levi's", "Kohl's"],
#  '81402': ['Converse', 'BCBGMAXAZRIA', 'Old Navy', 'Target'],
#  '84916': ['6pm.com'],
#  '86360': ['Nicole Miller',
#   'Kenneth Cole',
#   'New Balance',
#   'Old Navy',
#   'Target',
#   'Nordstrom',
#   'Shoebuy'],
#  '84914': ['French Connection',
#   'BCBGMAXAZRIA',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Gap',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Home Depot',
#   'Nordstrom'],
#  '84913': ['BCBGMAXAZRIA'],
#  '86367': ["Kohl's", 'Target', 'Home Depot'],
#  '89376': ["Levi's",
#   'Nambe',
#   'Banana Republic',
#   'Le Creuset',
#   'Ethan Allen',
#   'Crate & Barrel',
#   'Target',
#   'Nordstrom'],
#  '86365': ["Levi's",
#   'Tommy Hilfiger',
#   'Lacoste',
#   'Life is good',
#   'J.Crew',
#   "Kohl's",
#   "Lands' End",
#   'Old Navy',
#   'Target'],
#  '89378': ["Kohl's", 'Home Depot'],
#  '88710': ['Puma',
#   'KitchenAid',
#   'John Varvatos',
#   'Converse',
#   'French Connection',
#   'Gap',
#   'Restoration Hardware',
#   'J.Crew',
#   "Kohl's",
#   "Lands' End",
#   'Old Navy',
#   '6pm.com',
#   'Target',
#   'Home Depot',
#   'Nordstrom',
#   'Shoebuy'],
#  '86369': ['Hanky Panky', 'BCBGMAXAZRIA', 'Crate & Barrel', 'Nordstrom'],
#  '84919': ['New Balance', 'Converse', 'Old Navy', 'Target', 'Home Depot'],
#  '89176': ["Kohl's", 'Target'],
#  '89173': ["Levi's",
#   'Columbia',
#   'Tommy Hilfiger',
#   'Puma',
#   'Kenneth Cole',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Calvin Klein',
#   'Betsey Johnson',
#   'John Varvatos',
#   'Cuisinart',
#   'Lacoste',
#   'Villeroy & Boch',
#   'New Balance',
#   'Converse',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Crocs',
#   'Nine West',
#   'Nambe',
#   'Guess',
#   'Lenox',
#   'DKNY',
#   'Banana Republic',
#   'Kosta Boda',
#   'Mikasa',
#   'Gap',
#   'Life is good',
#   'Le Creuset',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'Horchow',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   '6pm.com',
#   'CB2',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Serena and Lily'],
#  '89170': ['Restoration Hardware', 'Express', 'Home Depot'],
#  '89171': ['Lacoste'],
#  '82198': ["Levi's",
#   'Tommy Hilfiger',
#   'Puma',
#   'KitchenAid',
#   'Calvin Klein',
#   'Cuisinart',
#   'Lacoste',
#   'New Balance',
#   'Nine West',
#   'Old Navy',
#   'Home Depot',
#   'Nordstrom'],
#  '87969': ["Kohl's", 'Home Depot'],
#  '82448': ['Melissa & Doug',
#   'KitchenAid',
#   'Cuisinart',
#   'Gap',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Home Depot'],
#  '88659': ["Levi's",
#   'KitchenAid',
#   'Converse',
#   'Guess',
#   'Gap',
#   'Old Navy',
#   'Target'],
#  '82443': ['Puma',
#   'Lacoste',
#   'Crocs',
#   'Elie Tahari',
#   'Banana Republic',
#   'Kate Spade',
#   'Gap',
#   'J.Crew',
#   "Kohl's",
#   "Lands' End",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Serena and Lily'],
#  '82440': ['Columbia',
#   'Nicole Miller',
#   'KitchenAid',
#   'Betsey Johnson',
#   'Cuisinart',
#   'Lacoste',
#   'Converse',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Elie Tahari',
#   'Nine West',
#   'Diesel',
#   'Nambe',
#   'Guess',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'Express',
#   'Old Navy',
#   'Crate & Barrel',
#   'CB2',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '82446': ['Guess'],
#  '82197': ['Kenneth Cole',
#   'KitchenAid',
#   'Calvin Klein',
#   'Cuisinart',
#   'Guess',
#   'Banana Republic',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target'],
#  '82196': ['Nine West', "Kohl's", 'Old Navy'],
#  '85450': ['Crate & Barrel'],
#  '88625': ["Levi's",
#   'Hanky Panky',
#   'KitchenAid',
#   'Cuisinart',
#   'Converse',
#   'Nine West',
#   'Banana Republic',
#   'Gap',
#   'Ethan Allen',
#   'J.Crew',
#   "Kohl's",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Crate & Barrel',
#   '6pm.com',
#   'Target',
#   'Home Depot',
#   'Nordstrom'],
#  '88155': ['Converse',
#   'Crocs',
#   'Steve Madden',
#   'Banana Republic',
#   'Life is good',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Forever 21',
#   'Target',
#   'Nordstrom',
#   'Zara'],
#  '88154': ['Gap',
#   'Restoration Hardware',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Container Store',
#   'Home Depot'],
#  '88153': ['Diesel', 'Ethan Allen', 'Target', 'Home Depot'],
#  '88152': ['Banana Republic', 'Express'],
#  '91514': ["Levi's", 'Converse', 'Steve Madden', 'Guess', 'Old Navy'],
#  '90246': ['BCBGMAXAZRIA', 'Steve Madden', 'Guess', 'DKNY', 'Gap', 'Target'],
#  '90763': ['Nicole Miller',
#   'Kenneth Cole',
#   'KitchenAid',
#   'Cuisinart',
#   'Lacoste',
#   'New Balance',
#   'Crocs',
#   'Nine West',
#   'Banana Republic',
#   'Gap',
#   'Le Creuset',
#   'J.Crew',
#   'Express',
#   "Lands' End",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Crate & Barrel',
#   '6pm.com',
#   'Target',
#   'Container Store'],
#  '88628': ["Levi's", 'Calvin Klein', 'Converse', "Kohl's", 'Target'],
#  '88395': ['KitchenAid',
#   'Cuisinart',
#   'New Balance',
#   'Nine West',
#   'Mikasa',
#   'Gap',
#   'Le Creuset',
#   'Old Navy',
#   'CB2',
#   'Container Store',
#   'Home Depot'],
#  '81249': ['Home Depot'],
#  '88397': ['Old Navy'],
#  '82992': ['Crocs',
#   'Nine West',
#   'Restoration Hardware',
#   "Kohl's",
#   'Last Call by Neiman Marcus',
#   'Target'],
#  '82995': ["Kohl's", 'Old Navy', 'Target', 'Home Depot'],
#  '88390': ['Crate & Barrel', 'Home Depot'],
#  '82997': ["Levi's",
#   'Nine West',
#   'Express',
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Shoebuy'],
#  '82996': ['Converse', 'Steve Madden', 'Gap', 'Express', 'Old Navy', 'Target'],
#  '81536': ['Home Depot'],
#  '81537': ['Old Navy'],
#  '81243': ["Kohl's", 'Target', 'Home Depot'],
#  '81532': ['Columbia',
#   'KitchenAid',
#   'Calvin Klein',
#   'Converse',
#   'Nine West',
#   'Guess',
#   'Kate Spade',
#   'Gap',
#   'Le Creuset',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   '6pm.com',
#   'Target',
#   'Home Depot',
#   'Nordstrom',
#   'Shoebuy'],
#  '89372': ['Nicole Miller',
#   'Kenneth Cole',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Lacoste',
#   'New Balance',
#   'Converse',
#   'BCBGMAXAZRIA',
#   'Crocs',
#   'Elie Tahari',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'Kate Spade',
#   'Le Creuset',
#   'Restoration Hardware',
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Crate & Barrel',
#   'Home Depot'],
#  '82229': ['Calvin Klein',
#   'BCBGMAXAZRIA',
#   'Steve Madden',
#   'Guess',
#   'Express',
#   'Old Navy'],
#  '81247': ['Ethan Allen',
#   'Restoration Hardware',
#   'Crate & Barrel',
#   'Container Store'],
#  '87585': ["Levi's",
#   'KitchenAid',
#   'J.Crew',
#   'Express',
#   "Lands' End",
#   'Crate & Barrel',
#   'Container Store'],
#  '89373': ["Kohl's"],
#  '87581': ['Life is good'],
#  '87580': ['Melissa & Doug'],
#  '80178': ['Banana Republic'],
#  '89374': ["Levi's",
#   'Nicole Miller',
#   'Hanky Panky',
#   'John Varvatos',
#   'BCBGMAXAZRIA',
#   'Elie Tahari',
#   'Restoration Hardware',
#   'J.Crew'],
#  '85458': ['Express', "Kohl's", 'Old Navy', 'Target', 'Home Depot'],
#  '86986': ['Old Navy'],
#  '86982': ['Hanky Panky',
#   'Cuisinart',
#   'BCBGMAXAZRIA',
#   'Nambe',
#   'Kosta Boda',
#   'Mikasa',
#   'Kate Spade',
#   'Last Call by Neiman Marcus',
#   'Crate & Barrel',
#   'Target',
#   'Nordstrom'],
#  '86980': ['KitchenAid',
#   'Cuisinart',
#   'New Balance',
#   'Elie Tahari',
#   'Kate Spade',
#   'Le Creuset',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'Horchow',
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Home Depot',
#   'Nordstrom'],
#  '80598': ["Levi's",
#   'Columbia',
#   'Nicole Miller',
#   'Nine West',
#   'Target',
#   'Home Depot'],
#  '91421': ["Kohl's", 'Old Navy'],
#  '80590': ['Columbia',
#   'Tommy Hilfiger',
#   'Puma',
#   'Kenneth Cole',
#   'KitchenAid',
#   'Calvin Klein',
#   'Lacoste',
#   'New Balance',
#   'Converse',
#   'Guess',
#   'Banana Republic',
#   'Life is good',
#   'Old Navy',
#   'Home Depot',
#   'Shoebuy'],
#  '81334': ['Banana Republic', 'Express'],
#  '81335': ['Burberry',
#   'John Varvatos',
#   'French Connection',
#   'Gucci',
#   'Ralph Lauren',
#   'J.Crew',
#   'Crate & Barrel',
#   'CB2',
#   'Nordstrom'],
#  '81336': ['Old Navy'],
#  '88020': ['KitchenAid',
#   "Kohl's",
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '88027': ['Tommy Hilfiger',
#   'Kenneth Cole',
#   'Lacoste',
#   'New Balance',
#   'BCBGMAXAZRIA',
#   'J.Crew',
#   "Lands' End",
#   'Old Navy',
#   'Target',
#   'Nordstrom'],
#  '88026': ["Levi's", "Kohl's", 'Old Navy', 'Target'],
#  '89625': ['Home Depot'],
#  '88024': ['John Varvatos',
#   'BCBGMAXAZRIA',
#   'Crocs',
#   'Nine West',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'Restoration Hardware',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Nordstrom'],
#  '80207': ['Hanky Panky', 'Last Call by Neiman Marcus', 'Nordstrom'],
#  '80206': ['Elie Tahari'],
#  '80205': ["Levi's",
#   'KitchenAid',
#   'Cuisinart',
#   'Crocs',
#   'Nine West',
#   'Restoration Hardware',
#   'Express',
#   "Kohl's",
#   "Lands' End",
#   'Target',
#   'Container Store',
#   'Home Depot'],
#  '80204': ['Shoebuy'],
#  '85323': ['Banana Republic', "Kohl's", 'Target', 'Home Depot'],
#  '80750': ["Levi's",
#   'Tommy Hilfiger',
#   'Puma',
#   'KitchenAid',
#   'Cuisinart',
#   'Converse',
#   'French Connection',
#   'Guess',
#   'Lenox',
#   'DKNY',
#   'Mikasa',
#   'Gap',
#   'Le Creuset',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Container Store',
#   'Home Depot'],
#  '90536': ['KitchenAid',
#   'Steve Madden',
#   'Banana Republic',
#   'Gap',
#   'Restoration Hardware',
#   'Express',
#   'Crate & Barrel',
#   'Target'],
#  '85138': ['Puma'],
#  '82532': ['Puma',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Cuisinart',
#   'French Connection',
#   'Crocs',
#   'Nine West',
#   'Diesel',
#   'Banana Republic',
#   'Gap',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '82530': ['CB2'],
#  '82534': ['Puma',
#   'Kenneth Cole',
#   'Lacoste',
#   'Banana Republic',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target'],
#  '81622': ["Levi's", 'Lacoste', 'Guess'],
#  '81620': ['Hanky Panky',
#   'Steve Madden',
#   'Diesel',
#   'Banana Republic',
#   'Kate Spade',
#   'Express',
#   "Kohl's",
#   '6pm.com',
#   'Target',
#   'Nordstrom',
#   'Shoebuy'],
#  '81621': ['Nicole Miller'],
#  '81625': ['Hanky Panky',
#   'Kenneth Cole',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Calvin Klein',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Crocs',
#   'Nine West',
#   'Steve Madden',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'Le Creuset',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   '6pm.com',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom',
#   'Shoebuy'],
#  '91070': ['Melissa & Doug',
#   'Calvin Klein',
#   'Banana Republic',
#   'Gap',
#   "Lands' End",
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '85358': ['Calvin Klein', 'Mikasa', 'Old Navy'],
#  '91072': ['KitchenAid', 'Guess', 'Home Depot'],
#  '89278': ['Home Depot'],
#  '80279': ['Hanky Panky',
#   'New Balance',
#   'French Connection',
#   'Elie Tahari',
#   'Banana Republic',
#   'Ethan Allen',
#   'J.Crew',
#   'Last Call by Neiman Marcus',
#   'Crate & Barrel',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '85911': ['Lenox'],
#  '84971': ["Levi's",
#   'Nicole Miller',
#   'Hanky Panky',
#   'Puma',
#   'Kenneth Cole',
#   'KitchenAid',
#   'Calvin Klein',
#   'Betsey Johnson',
#   'Cuisinart',
#   'Converse',
#   'French Connection',
#   'Nine West',
#   'Steve Madden',
#   'Banana Republic',
#   'Mikasa',
#   'Le Creuset',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'CB2',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom',
#   'Shoebuy'],
#  '90792': ['Express'],
#  '90562': ["Kohl's"],
#  '90224': ['Le Creuset'],
#  '84123': ["Levi's",
#   'Tommy Hilfiger',
#   'Kenneth Cole',
#   'Betsey Johnson',
#   'Converse',
#   'Steve Madden',
#   'Banana Republic',
#   'Gap',
#   'Express',
#   'Old Navy',
#   'Target'],
#  '90222': ["Levi's",
#   'Steve Madden',
#   'DKNY',
#   "Kohl's",
#   'Crate & Barrel',
#   'Container Store'],
#  '85183': ['Prada',
#   'New Balance',
#   'BCBGMAXAZRIA',
#   "L'occitane",
#   'Diesel',
#   'Guess',
#   'Gap',
#   'J.Crew',
#   'Abercrombie & Fitch',
#   'American Eagle',
#   'Old Navy',
#   'Target',
#   'Nordstrom',
#   'Discovery Channel Store'],
#  '85182': ['Hanky Panky',
#   'Kate Spade',
#   'Le Creuset',
#   'Restoration Hardware',
#   'J.Crew',
#   'Target',
#   'Container Store',
#   'Nordstrom'],
#  '90228': ["Levi's", 'Nine West', 'Target', 'Nordstrom'],
#  '90913': ['Crocs',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Home Depot'],
#  '80119': ['KitchenAid',
#   'Gap',
#   'Life is good',
#   'J.Crew',
#   "Kohl's",
#   "Lands' End",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '81755': ['Kate Spade', 'J.Crew', "Kohl's", 'Target'],
#  '81772': ['New Balance', "Kohl's", 'Old Navy', 'Target'],
#  '81750': ['KitchenAid',
#   'Restoration Hardware',
#   'Crate & Barrel',
#   'Container Store',
#   'Home Depot'],
#  '80113': ['Guess'],
#  '85430': ["Levi's",
#   'Columbia',
#   'Tommy Hilfiger',
#   'Kenneth Cole',
#   'Calvin Klein',
#   'Lacoste',
#   'New Balance',
#   'BCBGMAXAZRIA',
#   'Elie Tahari',
#   'Nine West',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Kate Spade',
#   'Gap',
#   'Express',
#   "Kohl's",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   '6pm.com',
#   'Target',
#   'Nordstrom',
#   'Shoebuy'],
#  '80117': ['Banana Republic', 'Express', 'Nordstrom'],
#  '89273': ['Villeroy & Boch',
#   'French Connection',
#   'Steve Madden',
#   'Express',
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Nordstrom'],
#  '91285': ['Kenneth Cole',
#   'Banana Republic',
#   'Restoration Hardware',
#   'J.Crew',
#   'Crate & Barrel',
#   'Nordstrom'],
#  '85611': ['Target'],
#  '89272': ['Calvin Klein', 'Nordstrom'],
#  '90008': ['Steve Madden', "Macy's", "Kohl's", 'Old Navy', 'Forever 21'],
#  '80797': ['KitchenAid', 'Guess', "Macy's"],
#  '91361': ['KitchenAid', "Kohl's", 'Old Navy', 'Target'],
#  '85619': ['Guess', 'Gap', 'Target'],
#  '90000': ["Levi's",
#   'Nicole Miller',
#   'KitchenAid',
#   'Cuisinart',
#   'Lacoste',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'DKNY',
#   'Banana Republic',
#   'Kate Spade',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Crate & Barrel',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom',
#   'Serena and Lily'],
#  '87260': ['Gap', "Macy's", 'Target'],
#  '89383': ['BCBGMAXAZRIA',
#   'Banana Republic',
#   'Kate Spade',
#   'Target',
#   'Nordstrom'],
#  '80374': ['French Connection', 'Nordstrom'],
#  '84696': ['Betsey Johnson'],
#  '85055': ['KitchenAid',
#   'New Balance',
#   'Le Creuset',
#   'Restoration Hardware',
#   "Lands' End",
#   'Crate & Barrel',
#   '6pm.com',
#   'Container Store',
#   'Nordstrom',
#   'Shoebuy'],
#  '90312': ['Melissa & Doug', 'KitchenAid'],
#  '85056': ['Banana Republic'],
#  '80571': ['Home Depot'],
#  '85050': ["Levi's",
#   'Columbia',
#   'Kenneth Cole',
#   'KitchenAid',
#   'Calvin Klein',
#   'Betsey Johnson',
#   'Lacoste',
#   'Converse',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Kate Spade',
#   'J.Crew',
#   'Express',
#   'Target',
#   'Nordstrom',
#   'Shoebuy'],
#  '84058': ['Target'],
#  '84059': ['Hanky Panky',
#   'KitchenAid',
#   'Cuisinart',
#   'French Connection',
#   'Kate Spade',
#   'Gap',
#   'Restoration Hardware',
#   'Horchow',
#   'J.Crew',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Nordstrom',
#   'Serena and Lily'],
#  '84056': ['Lacoste',
#   'Nine West',
#   'Banana Republic',
#   'Kate Spade',
#   'Gap',
#   'Target',
#   'Nordstrom'],
#  '90266': ['Banana Republic',
#   'Gap',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Target'],
#  '85059': ["Levi's",
#   'Melissa & Doug',
#   'KitchenAid',
#   'Calvin Klein',
#   'Cuisinart',
#   'Converse',
#   'Guess',
#   'J.Crew',
#   "Kohl's",
#   'Target',
#   'Nordstrom'],
#  '84050': ['Calvin Klein'],
#  '85508': ['Tommy Hilfiger',
#   'Puma',
#   'Calvin Klein',
#   'Lacoste',
#   'Nine West',
#   'Guess',
#   'Banana Republic',
#   'Gap',
#   'Old Navy'],
#  '84677': ['Target'],
#  '86566': ['Kosta Boda', 'Target'],
#  '84675': ['John Varvatos', 'J.Crew', 'Home Depot'],
#  '86560': ["Kohl's"],
#  '86561': ['Target'],
#  '86562': ["Kohl's", 'Target', 'Home Depot'],
#  '86563': ['Converse', "Kohl's", 'Old Navy', 'Target'],
#  '87887': ['Converse', 'Mikasa', 'Target'],
#  '83585': ['KitchenAid',
#   'Cuisinart',
#   'Banana Republic',
#   'Gap',
#   'Le Creuset',
#   'Restoration Hardware',
#   'J.Crew',
#   "Kohl's",
#   'Crate & Barrel',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '83584': ['Puma',
#   'KitchenAid',
#   'Cuisinart',
#   'Converse',
#   'Target',
#   'Home Depot'],
#  '84678': ['Target'],
#  '83586': ['Express', 'Target', 'Nordstrom'],
#  '88092': ['KitchenAid',
#   'Cuisinart',
#   'Converse',
#   'Le Creuset',
#   'Restoration Hardware',
#   'Crate & Barrel',
#   'Target',
#   'Home Depot'],
#  '87963': ['Tommy Hilfiger',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Cuisinart',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Lenox',
#   'DKNY',
#   'Gap',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Shoebuy'],
#  '91075': ['Nicole Miller',
#   'Nine West',
#   'Steve Madden',
#   'Banana Republic',
#   'J.Crew',
#   'Old Navy',
#   'Crate & Barrel'],
#  '80971': ['KitchenAid',
#   'Nine West',
#   'Le Creuset',
#   'Express',
#   'Target',
#   'Home Depot',
#   'Nordstrom'],
#  '84584': ['Target'],
#  '84587': ['Nine West', '6pm.com', 'Nordstrom'],
#  '91592': ['Melissa & Doug', "Kohl's", 'Target', 'Nordstrom'],
#  '84582': ['Target'],
#  '83277': ['Calvin Klein',
#   'Betsey Johnson',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Steve Madden',
#   'Banana Republic',
#   'Kate Spade',
#   'Ann Taylor',
#   'Express',
#   'Crate & Barrel',
#   'Target'],
#  '83276': ["Levi's",
#   'KitchenAid',
#   'Cuisinart',
#   'Nine West',
#   "Kohl's",
#   'Old Navy',
#   'Target'],
#  '83274': ['Tommy Hilfiger',
#   'Puma',
#   'Kenneth Cole',
#   'French Connection',
#   'Crocs',
#   'DKNY',
#   'Kate Spade',
#   'Life is good',
#   'Restoration Hardware',
#   'Express',
#   "Lands' End",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Target',
#   'Home Depot'],
#  '83273': ['Columbia',
#   'Tommy Hilfiger',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Cuisinart',
#   'BCBGMAXAZRIA',
#   'Lenox',
#   'Horchow',
#   'Express',
#   "Lands' End",
#   'Old Navy',
#   'Crate & Barrel',
#   'Serena and Lily'],
#  '83272': ['KitchenAid',
#   'Cuisinart',
#   'BCBGMAXAZRIA',
#   'Banana Republic',
#   'Express',
#   'Old Navy',
#   'Crate & Barrel',
#   'Target'],
#  '83903': ['Target'],
#  '83902': ['Nicole Miller',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Calvin Klein',
#   'Converse',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Steve Madden',
#   'Guess',
#   'Kate Spade',
#   'Restoration Hardware',
#   'J.Crew',
#   'Old Navy',
#   'Crate & Barrel',
#   'Home Depot'],
#  '90610': ["Levi's",
#   'Columbia',
#   'Kenneth Cole',
#   'KitchenAid',
#   'New Balance',
#   'Crocs',
#   'Nine West',
#   'Steve Madden',
#   'Guess',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   '6pm.com',
#   'Target',
#   'Nordstrom'],
#  '87965': ['Crate & Barrel', 'Home Depot', 'Nordstrom'],
#  '91289': ['Calvin Klein',
#   'BCBGMAXAZRIA',
#   'Banana Republic',
#   'Express',
#   '6pm.com'],
#  '84272': ['Columbia',
#   'KitchenAid',
#   'Cuisinart',
#   'Banana Republic',
#   'Le Creuset',
#   'Crate & Barrel',
#   'Container Store',
#   'Home Depot',
#   'Shoebuy'],
#  '86693': ['Steve Madden',
#   'Guess',
#   'Banana Republic',
#   'Express',
#   'Target',
#   'Nordstrom'],
#  '86691': ["Kohl's", "Lands' End", 'Target', 'Home Depot'],
#  '89969': ['Calvin Klein', 'Gap', 'Target'],
#  '83290': ['Calvin Klein',
#   'Steve Madden',
#   'Banana Republic',
#   'Gap',
#   'Express',
#   'Target',
#   'Nordstrom'],
#  '89617': ['Kenneth Cole',
#   'New Balance',
#   'Elie Tahari',
#   'Steve Madden',
#   'Old Navy',
#   '6pm.com',
#   'Target',
#   'Home Depot'],
#  '89966': ['Columbia',
#   'Puma',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Guess',
#   'Banana Republic',
#   'Ethan Allen',
#   'Express',
#   'Old Navy',
#   'Crate & Barrel',
#   'Home Depot'],
#  '89613': ['Tommy Hilfiger',
#   'Nicole Miller',
#   'Betsey Johnson',
#   'Cuisinart',
#   'Steve Madden',
#   'Guess',
#   'Restoration Hardware',
#   'Crate & Barrel',
#   '6pm.com',
#   'Shoebuy'],
#  '80805': ['Melissa & Doug',
#   'Mikasa',
#   'Gap',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot'],
#  '80804': ["Levi's", 'John Varvatos', 'Mikasa', 'Home Depot'],
#  '80801': ['BUCKLE'],
#  '80800': ['Restoration Hardware', 'Nordstrom'],
#  '80802': ['Columbia', 'Target', 'Home Depot'],
#  '87109': ['Home Depot'],
#  '89548': ['Columbia',
#   'Kenneth Cole',
#   'Melissa & Doug',
#   'Gap',
#   'Ethan Allen',
#   "Kohl's",
#   "Lands' End",
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot'],
#  '87101': ["Kohl's", 'Old Navy', 'Target'],
#  '87100': ['Kenneth Cole',
#   'KitchenAid',
#   'Cuisinart',
#   'Guess',
#   'Banana Republic',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot'],
#  '87105': ['Tommy Hilfiger',
#   'Puma',
#   'KitchenAid',
#   'Lacoste',
#   'BCBGMAXAZRIA',
#   'Crocs',
#   'Guess',
#   'DKNY',
#   'Express',
#   'Old Navy',
#   'Crate & Barrel',
#   'CB2',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '87104': ['Lacoste'],
#  '83619': ['Columbia', 'Home Depot'],
#  '89922': ['Tommy Hilfiger',
#   'KitchenAid',
#   'Calvin Klein',
#   'Gap',
#   'Old Navy',
#   'Target'],
#  '84474': ['Calvin Klein', 'Lacoste'],
#  '84475': ["Levi's",
#   'Puma',
#   'Crocs',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot'],
#  '84476': ['Melissa & Doug',
#   'KitchenAid',
#   'Nine West',
#   'Steve Madden',
#   'Banana Republic',
#   'J.Crew',
#   'Crate & Barrel',
#   '6pm.com',
#   'CB2',
#   'Target',
#   'Container Store',
#   'Nordstrom'],
#  '83612': ["Kohl's", 'Old Navy', 'Target', 'Home Depot'],
#  '83123': ['Target', 'Home Depot'],
#  '83126': ['Restoration Hardware',
#   'CB2',
#   'Container Store',
#   'Serena and Lily'],
#  '83125': ['Banana Republic', "Macy's", 'Old Navy', 'Container Store'],
#  '85126': ['BCBGMAXAZRIA',
#   'Nine West',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'J.Crew',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Nordstrom',
#   'Shoebuy'],
#  '86186': ['Melissa & Doug',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Express',
#   'Old Navy',
#   'Crate & Barrel',
#   'Target'],
#  '90743': ['Kenneth Cole',
#   'DKNY',
#   'Restoration Hardware',
#   'Last Call by Neiman Marcus',
#   'Nordstrom'],
#  '86184': ['Guess', 'DKNY', 'Express', "Kohl's", 'Old Navy', 'Target'],
#  '86185': ['Last Call by Neiman Marcus'],
#  '89767': ['Betsey Johnson',
#   'BCBGMAXAZRIA',
#   'Elie Tahari',
#   'DKNY',
#   'Banana Republic',
#   'Last Call by Neiman Marcus',
#   'Nordstrom'],
#  '86183': ['Columbia',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Calvin Klein',
#   'Cuisinart',
#   'Lacoste',
#   'Villeroy & Boch',
#   'New Balance',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'Diesel',
#   'Nambe',
#   'Guess',
#   'Lenox',
#   'DKNY',
#   'Banana Republic',
#   'Kosta Boda',
#   'Mikasa',
#   'Kate Spade',
#   'Gap',
#   'Le Creuset',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'Horchow',
#   'Express',
#   "Kohl's",
#   'Last Call by Neiman Marcus',
#   'Pottery Barn',
#   'Crate & Barrel',
#   '6pm.com',
#   'CB2',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom',
#   'Serena and Lily',
#   'Shoebuy'],
#  '85424': ['Diesel'],
#  '87615': ['Gap', 'Old Navy', 'Home Depot'],
#  '86748': ['New Balance', 'Home Depot'],
#  '86744': ['Horchow'],
#  '83765': ['Calvin Klein'],
#  '85683': ['KitchenAid',
#   'Calvin Klein',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'Old Navy',
#   'Home Depot'],
#  '87619': ['Calvin Klein', 'New Balance', 'Life is good', 'Target'],
#  '88627': ['Banana Republic'],
#  '91661': ['Calvin Klein'],
#  '86743': ['Target'],
#  '83056': ['Home Depot'],
#  '83055': ['Banana Republic'],
#  '83726': ["Kohl's"],
#  '83053': ['Nicole Miller'],
#  '83052': ["Levi's",
#   'KitchenAid',
#   'Cuisinart',
#   'New Balance',
#   'Converse',
#   'Banana Republic',
#   'Gap',
#   'Life is good',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   "Lands' End",
#   'Old Navy',
#   'LL Bean',
#   'Target'],
#  '83723': ['Express', 'Target', 'Nordstrom'],
#  '83722': ["Levi's",
#   'Puma',
#   'Kenneth Cole',
#   'Melissa & Doug',
#   'Calvin Klein',
#   'John Varvatos',
#   'Cuisinart',
#   'Lacoste',
#   'Converse',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'Restoration Hardware',
#   'Express',
#   'Pottery Barn',
#   'Crate & Barrel',
#   'Janie and Jack',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '91464': ["Levi's",
#   'Lenox',
#   'Life is good',
#   "Kohl's",
#   "Lands' End",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot'],
#  '91460': ['Lacoste', 'Nike', 'Target', 'Nordstrom'],
#  '91463': ["Levi's", 'Betsey Johnson', 'Converse', 'Nordstrom'],
#  '83058': ['Puma',
#   'Lacoste',
#   'Steve Madden',
#   'Diesel',
#   'Brookstone',
#   'Lenox',
#   'Banana Republic',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'J.Crew',
#   'Express',
#   'Pottery Barn',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot'],
#  '89547': ['KitchenAid',
#   'Betsey Johnson',
#   'Cuisinart',
#   'French Connection',
#   'Steve Madden',
#   'Kate Spade',
#   'Express'],
#  '91687': ['Guess'],
#  '89816': ['Home Depot'],
#  '89543': ['Hanky Panky',
#   'Banana Republic',
#   'Restoration Hardware',
#   'J.Crew',
#   'Crate & Barrel',
#   'CB2'],
#  '91680': ['Puma', 'BCBGMAXAZRIA', 'CB2'],
#  '88818': ['Banana Republic',
#   'Gap',
#   'J.Crew',
#   'Old Navy',
#   'Crate & Barrel',
#   'Target'],
#  '89540': ["Levi's",
#   'Restoration Hardware',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot'],
#  '88816': ['Last Call by Neiman Marcus'],
#  '88361': ['Tommy Hilfiger'],
#  '88814': ['Calvin Klein', 'Banana Republic'],
#  '88366': ['Nine West', '6pm.com'],
#  '88367': ['Target'],
#  '87579': ['Puma',
#   'KitchenAid',
#   'Cuisinart',
#   'Crocs',
#   'Elie Tahari',
#   'Kate Spade',
#   'Gap',
#   'Le Creuset',
#   'Restoration Hardware',
#   'J.Crew',
#   "Lands' End",
#   'Crate & Barrel',
#   'CB2',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '88568': ['Nicole Miller',
#   'Melissa & Doug',
#   'Lacoste',
#   'Elie Tahari',
#   'Lenox',
#   'Mikasa',
#   'Kate Spade',
#   'Nordstrom'],
#  '87570': ["Levi's",
#   'Columbia',
#   'Tommy Hilfiger',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Betsey Johnson',
#   'Cuisinart',
#   'Villeroy & Boch',
#   'Converse',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Steve Madden',
#   'Free People',
#   'Diesel',
#   'Nambe',
#   'Guess',
#   'Lenox',
#   'DKNY',
#   'Kosta Boda',
#   'Mikasa',
#   'Kate Spade',
#   'Gap',
#   'Le Creuset',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'Horchow',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Anthropologie',
#   'Crate & Barrel',
#   'CB2',
#   'Target',
#   'Container Store',
#   'H&M',
#   'Home Depot',
#   'Karmaloop',
#   'Nordstrom',
#   'Serena and Lily',
#   'Shoebuy'],
#  '82051': ['Betsey Johnson', 'Diesel', "Kohl's", 'Target', 'Home Depot'],
#  '87573': ['Banana Republic', 'Le Creuset'],
#  '87574': ['New Balance',
#   'Nine West',
#   'Steve Madden',
#   'Kate Spade',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Shoebuy'],
#  '87575': ["Levi's",
#   'Columbia',
#   'New Balance',
#   'Old Navy',
#   'Target',
#   'Home Depot'],
#  '82056': ['Calvin Klein',
#   'Steve Madden',
#   'Banana Republic',
#   'Gap',
#   'Target',
#   'Nordstrom'],
#  '85983': ['Columbia',
#   'KitchenAid',
#   'Nine West',
#   'Nambe',
#   'DKNY',
#   'Banana Republic',
#   'Kosta Boda',
#   'Mikasa',
#   'Restoration Hardware',
#   "Kohl's",
#   'Crate & Barrel',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '85981': ["Levi's",
#   'Calvin Klein',
#   'Lacoste',
#   'True Religion',
#   'Converse',
#   'Gucci',
#   'Nike',
#   'Banana Republic',
#   'Ralph Lauren',
#   'Gap',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Nordstrom',
#   'Shoebuy'],
#  '85987': ['Nine West', 'Old Navy', 'Target'],
#  '87778': ['Nicole Miller',
#   'Kenneth Cole',
#   'KitchenAid',
#   'Calvin Klein',
#   'Betsey Johnson',
#   'Cuisinart',
#   'BCBGMAXAZRIA',
#   'Elie Tahari',
#   'DKNY',
#   'Banana Republic',
#   'Ethan Allen',
#   'J.Crew',
#   'Express',
#   'Crate & Barrel',
#   'Container Store',
#   'Nordstrom'],
#  '87779': ['Target'],
#  '87776': ['KitchenAid',
#   'Lacoste',
#   'Crocs',
#   'Banana Republic',
#   "Kohl's",
#   'Target',
#   'Nordstrom'],
#  '87777': ['Target'],
#  '87774': ['KitchenAid', 'Cuisinart', "Kohl's", 'Old Navy', 'Target'],
#  '87804': ["Levi's",
#   'Columbia',
#   'Tommy Hilfiger',
#   'Nicole Miller',
#   'Hanky Panky',
#   'Puma',
#   'Kenneth Cole',
#   'KitchenAid',
#   'Calvin Klein',
#   'Betsey Johnson',
#   'Cuisinart',
#   'Lacoste',
#   'New Balance',
#   'Converse',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Crocs',
#   'Elie Tahari',
#   'Nine West',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Kate Spade',
#   'Gap',
#   'Life is good',
#   'Le Creuset',
#   'Ethan Allen',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   "Lands' End",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom',
#   'Serena and Lily',
#   'Shoebuy'],
#  '85071': ["Levi's",
#   'Puma',
#   'Kenneth Cole',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Calvin Klein',
#   'Cuisinart',
#   'Converse',
#   'BCBGMAXAZRIA',
#   'Steve Madden',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Container Store',
#   'Home Depot'],
#  '87771': ['New Balance',
#   'Steve Madden',
#   'Express',
#   "Kohl's",
#   "Lands' End",
#   'Old Navy',
#   'Container Store'],
#  '90534': ['Nine West',
#   'Banana Republic',
#   'Gap',
#   'Le Creuset',
#   'Restoration Hardware',
#   'J.Crew',
#   'Old Navy',
#   'Crate & Barrel',
#   'CB2',
#   'Target',
#   'Container Store',
#   'Nordstrom',
#   'Serena and Lily'],
#  '88964': ["Kohl's", 'Container Store', 'Home Depot'],
#  '89582': ['Express'],
#  '89984': ['New Balance', 'Gap'],
#  '88091': ['KitchenAid', 'Ann Taylor', 'Old Navy', 'Target'],
#  '91205': ['Nine West',
#   'Banana Republic',
#   'Gap',
#   'Express',
#   'Old Navy',
#   'Target'],
#  '89581': ['KitchenAid',
#   'Nine West',
#   'Banana Republic',
#   'Restoration Hardware',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Home Depot'],
#  '90669': ["Levi's",
#   'Puma',
#   'KitchenAid',
#   'Calvin Klein',
#   'Lacoste',
#   'New Balance',
#   'Converse',
#   'Crocs',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'Express',
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   '6pm.com',
#   'Serena and Lily',
#   'Shoebuy'],
#  '88529': ['Hanky Panky',
#   'Betsey Johnson',
#   'John Varvatos',
#   'Kosta Boda',
#   'Kate Spade',
#   'Ethan Allen',
#   'Horchow',
#   'Target'],
#  '84862': ['Mikasa', 'Le Creuset'],
#  '90535': ['Kenneth Cole',
#   'Crate & Barrel',
#   'CB2',
#   'Container Store',
#   'Home Depot'],
#  '84902': ["Kohl's", 'Target', 'Home Depot'],
#  '84903': ['Melissa & Doug', 'Nine West', 'J.Crew', 'Nordstrom'],
#  '84904': ["Levi's",
#   'Melissa & Doug',
#   'KitchenAid',
#   'Calvin Klein',
#   'BCBGMAXAZRIA',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'J.Crew',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Home Depot',
#   'Nordstrom',
#   'Shoebuy'],
#  '89857': ["Levi's", 'Columbia', 'Converse', "Kohl's", 'Old Navy', 'Target'],
#  '86359': ['Express'],
#  '81438': ['Old Navy', 'Target'],
#  '81436': ['Banana Republic'],
#  '82379': ["Levi's",
#   'Tommy Hilfiger',
#   'Puma',
#   'Kenneth Cole',
#   'KitchenAid',
#   'Calvin Klein',
#   'Betsey Johnson',
#   'Cuisinart',
#   'Lacoste',
#   'Converse',
#   'BCBGMAXAZRIA',
#   'Crocs',
#   'Nine West',
#   'Steve Madden',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Kate Spade',
#   'Gap',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Nordstrom'],
#  '89381': ['KitchenAid',
#   'Cuisinart',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot'],
#  '81432': ['KitchenAid',
#   'Converse',
#   'Nine West',
#   'Steve Madden',
#   'Express',
#   "Kohl's",
#   'Crate & Barrel',
#   'Target',
#   'Nordstrom'],
#  '86351': ['KitchenAid',
#   'Cuisinart',
#   'BCBGMAXAZRIA',
#   'Guess',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '81430': ['Kenneth Cole',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Lacoste',
#   'Converse',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'DKNY',
#   'Old Navy',
#   'Crate & Barrel',
#   'Container Store',
#   'Home Depot'],
#  '82454': ["Lands' End"],
#  '82455': ['Tommy Hilfiger'],
#  '88498': ['KitchenAid',
#   'Cuisinart',
#   'BCBGMAXAZRIA',
#   'Banana Republic',
#   'Express',
#   'Target',
#   'Shoebuy'],
#  '80411': ['Old Navy'],
#  '89147': ['Cuisinart'],
#  '87971': ['Puma',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'Guess',
#   'Banana Republic',
#   "Kohl's",
#   'Old Navy',
#   'Target'],
#  '82452': ['Banana Republic', 'Kate Spade', "Kohl's", 'Target'],
#  '90989': ['Columbia',
#   'Crocs',
#   'Restoration Hardware',
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Pottery Barn',
#   'Crate & Barrel',
#   'Container Store',
#   'Home Depot'],
#  '88490': ["Kohl's", 'Old Navy', 'Container Store'],
#  '88491': ['Target', 'Home Depot'],
#  '82458': ['New Balance'],
#  '82459': ['Nine West',
#   'DKNY',
#   'Banana Republic',
#   'Express',
#   'Old Navy',
#   'Target',
#   'Nordstrom'],
#  '88494': ['Kenneth Cole'],
#  '88495': ["Levi's",
#   'Columbia',
#   'Puma',
#   'KitchenAid',
#   'Calvin Klein',
#   'John Varvatos',
#   'Lacoste',
#   'New Balance',
#   'Nine West',
#   'Nambe',
#   'Banana Republic',
#   'Gap',
#   'Express',
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   '6pm.com',
#   'CB2',
#   'Target',
#   'Nordstrom',
#   'Shoebuy'],
#  '91515': ['BCBGMAXAZRIA',
#   'Steve Madden',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'J.Crew',
#   'Express'],
#  '82999': ['KitchenAid',
#   'Nine West',
#   'Steve Madden',
#   'Guess',
#   'Banana Republic',
#   'Gap',
#   'Ethan Allen',
#   "Kohl's",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   '6pm.com',
#   'Target',
#   'Home Depot'],
#  '82188': ['Hanky Panky'],
#  '82189': ['Calvin Klein'],
#  '80414': ['Under Armour'],
#  '91841': ["Levi's",
#   'KitchenAid',
#   'Cuisinart',
#   'Converse',
#   'Gap',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Shoebuy'],
#  '91512': ['KitchenAid',
#   'John Varvatos',
#   'Crocs',
#   'Banana Republic',
#   'Gap',
#   'J.Crew',
#   'Express',
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '82180': ['Target'],
#  '85175': ['Melissa & Doug',
#   'Cuisinart',
#   'New Balance',
#   'Converse',
#   'Crocs',
#   'Le Creuset',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot'],
#  '89375': ['Restoration Hardware'],
#  '82187': ['KitchenAid',
#   'Cuisinart',
#   'Elie Tahari',
#   'Nine West',
#   'Steve Madden',
#   'DKNY',
#   'Banana Republic',
#   'Kate Spade',
#   'Gap',
#   'J.Crew',
#   'Express',
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot'],
#  '91848': ['New Balance', 'Elie Tahari', 'Nordstrom'],
#  '86502': ['Mikasa'],
#  '86215': ["Levi's", "Kohl's", 'Target', 'Nordstrom'],
#  '86805': ["Levi's",
#   'Columbia',
#   'Tommy Hilfiger',
#   'Puma',
#   'Kenneth Cole',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Calvin Klein',
#   'Cuisinart',
#   'Lacoste',
#   'New Balance',
#   'Converse',
#   'BCBGMAXAZRIA',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Gap',
#   'Le Creuset',
#   'Ethan Allen',
#   'J.Crew',
#   'Express',
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Home Depot',
#   'Nordstrom'],
#  '86500': ['Puma',
#   'Melissa & Doug',
#   'KitchenAid',
#   'New Balance',
#   'Converse',
#   'Guess',
#   'Lenox',
#   'Gap',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot'],
#  '88636': ['Home Depot'],
#  '91873': ['New Balance',
#   'Last Call by Neiman Marcus',
#   'Home Depot',
#   'Shoebuy'],
#  '86210': ['Columbia',
#   'Hanky Panky',
#   'New Balance',
#   'Converse',
#   'Banana Republic',
#   'Gap',
#   'Nordstrom'],
#  '88147': ['KitchenAid',
#   'Calvin Klein',
#   'BCBGMAXAZRIA',
#   'Guess',
#   "Victoria's Secret",
#   'Forever 21',
#   "Tilly's",
#   'Target',
#   'H&M',
#   'Nordstrom'],
#  '88148': ['New Balance',
#   'Nine West',
#   'Kate Spade',
#   "Kohl's",
#   "Lands' End",
#   'Old Navy',
#   'Target',
#   'Home Depot'],
#  '86506': ['Puma',
#   'Kenneth Cole',
#   'Calvin Klein',
#   'Lacoste',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'DKNY',
#   'Kate Spade',
#   'Shoebuy'],
#  '82228': ['Target'],
#  '85700': ['KitchenAid',
#   'New Balance',
#   'Converse',
#   'Gap',
#   'Life is good',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   "Lands' End",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot'],
#  '82983': ['Hanky Panky',
#   'Betsey Johnson',
#   'Converse',
#   'Steve Madden',
#   'Old Navy',
#   'Target',
#   'Nordstrom'],
#  '82980': ['Melissa & Doug',
#   'KitchenAid',
#   'BCBGMAXAZRIA',
#   'Crocs',
#   'Steve Madden',
#   'DKNY',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Shoebuy'],
#  '82981': ['Tommy Hilfiger',
#   'Nicole Miller',
#   'Hanky Panky',
#   'Puma',
#   'Kenneth Cole',
#   'KitchenAid',
#   'Calvin Klein',
#   'Betsey Johnson',
#   'Cuisinart',
#   'Lacoste',
#   'New Balance',
#   'Converse',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Mikasa',
#   'Kate Spade',
#   'Gap',
#   'Ethan Allen',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Crate & Barrel',
#   '6pm.com',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom',
#   'Shoebuy'],
#  '82986': ["Kohl's", 'Home Depot'],
#  '87194': ["Kohl's", 'Old Navy', "Children's Place", 'Target', 'Home Depot'],
#  '82236': ["Levi's",
#   'Puma',
#   'KitchenAid',
#   'Cuisinart',
#   'New Balance',
#   'Ethan Allen',
#   "Kohl's",
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Shoebuy'],
#  '82985': ['Target'],
#  '82238': ["Levi's",
#   'Puma',
#   'KitchenAid',
#   'Calvin Klein',
#   'Juicy Couture',
#   'New Balance',
#   'Converse',
#   'French Connection',
#   'Crocs',
#   'Coach',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'Abercrombie & Fitch',
#   'American Eagle',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Forever 21',
#   'Home Depot'],
#  '82989': ['Calvin Klein', 'Nine West', 'Guess', 'Express'],
#  '81504': ['Columbia', 'Old Navy', 'Home Depot'],
#  '91870': ['New Balance', 'Life is good', "Kohl's", 'Target'],
#  '87597': ['Banana Republic'],
#  '87594': ['Columbia',
#   'Puma',
#   'Melissa & Doug',
#   'Calvin Klein',
#   'Lacoste',
#   'Converse',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Crocs',
#   'Diesel',
#   'Banana Republic',
#   'Gap',
#   'J.Crew',
#   'Old Navy',
#   '6pm.com',
#   'Target'],
#  '87592': ['Melissa & Doug',
#   'KitchenAid',
#   'Restoration Hardware',
#   'Express',
#   'Crate & Barrel'],
#  '87198': ['Steve Madden', 'Express', 'Old Navy', 'Target'],
#  '81292': ['Banana Republic', 'Gap', 'Express', "Kohl's"],
#  '81296': ['Gap', 'Target'],
#  '84799': ['Columbia',
#   'KitchenAid',
#   'Betsey Johnson',
#   'Cuisinart',
#   'Nine West',
#   'Steve Madden',
#   'Gap',
#   'Life is good',
#   'Le Creuset',
#   'Horchow',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   '6pm.com',
#   'Target',
#   'Nordstrom'],
#  '90118': ['Melissa & Doug',
#   'Elie Tahari',
#   'Diesel',
#   'Gap',
#   'Le Creuset',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Nordstrom'],
#  '80581': ['Le Creuset',
#   'Restoration Hardware',
#   "Kohl's",
#   "Lands' End",
#   'Crate & Barrel'],
#  '80582': ['Banana Republic'],
#  '91888': ['Gap', "Kohl's", 'Old Navy', 'Target', 'Payless Shoes'],
#  '80586': ['Target'],
#  '81340': ["Kohl's", 'Home Depot'],
#  '81615': ['Express'],
#  '81342': ['Cuisinart'],
#  '88038': ['Steve Madden',
#   'Restoration Hardware',
#   'Old Navy',
#   'Target',
#   'Home Depot'],
#  '81612': ['Gap', 'Target'],
#  '80748': ['Banana Republic', 'Crate & Barrel', 'Shoebuy'],
#  '80747': ['Old Navy'],
#  '80742': ['Nicole Miller',
#   'KitchenAid',
#   'Calvin Klein',
#   'Cuisinart',
#   'BCBGMAXAZRIA',
#   'Elie Tahari',
#   'Nine West',
#   'Steve Madden',
#   'Le Creuset',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'Express',
#   'Crate & Barrel',
#   'Container Store',
#   'Home Depot',
#   'Serena and Lily'],
#  '80216': ['Lacoste'],
#  '88033': ['Diesel', 'Banana Republic', 'Shoebuy'],
#  '88382': ['KitchenAid', 'Converse', "Kohl's", 'Target'],
#  '81185': ['Vera Bradley', 'Gap', "Kohl's", 'Target', 'Home Depot', 'Shoebuy'],
#  '81183': ['Express'],
#  '82529': ["Levi's",
#   'Tommy Hilfiger',
#   'Calvin Klein',
#   'Lacoste',
#   'New Balance',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'J.Crew'],
#  '81181': ["Levi's",
#   'Calvin Klein',
#   'Lacoste',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'Guess',
#   'DKNY',
#   'Kate Spade',
#   "Kohl's",
#   'Last Call by Neiman Marcus',
#   '6pm.com',
#   'Target',
#   'Nordstrom',
#   'Shoebuy'],
#  '82526': ['Kate Spade', 'J.Crew'],
#  '81188': ['Lacoste', 'Banana Republic', 'Nordstrom'],
#  '86230': ['Nicole Miller',
#   'Kenneth Cole',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Cuisinart',
#   'BCBGMAXAZRIA',
#   'Steve Madden',
#   'Guess',
#   'Banana Republic',
#   'Kate Spade',
#   'Gap',
#   'J.Crew',
#   'Old Navy',
#   'Crate & Barrel',
#   'Target'],
#  '84859': ['Nambe'],
#  '86828': ['Old Navy'],
#  '90401': ['Kenneth Cole',
#   'KitchenAid',
#   'Calvin Klein',
#   'Lacoste',
#   'New Balance',
#   'Steve Madden',
#   'Guess',
#   'Banana Republic',
#   'J.Crew',
#   'Express'],
#  '85191': ["Levi's", 'New Balance', 'J.Crew'],
#  '85192': ['KitchenAid',
#   'Cuisinart',
#   'Nine West',
#   'Steve Madden',
#   'Guess',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot'],
#  '85193': ['Columbia',
#   'KitchenAid',
#   'Banana Republic',
#   'Le Creuset',
#   'Restoration Hardware',
#   'Crate & Barrel',
#   'Target'],
#  '88393': ['Kenneth Cole', 'Lacoste', 'Diesel', 'Target'],
#  '85199': ['Lacoste'],
#  '80104': ['Betsey Johnson'],
#  '85426': ['Banana Republic', 'Gap', 'J.Crew', "Lands' End", 'Target'],
#  '80100': ["Levi's",
#   'KitchenAid',
#   'Cuisinart',
#   'Converse',
#   "Kohl's",
#   "Lands' End",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Home Depot'],
#  '80102': ['Target', 'Home Depot'],
#  '85423': ['CB2', 'Container Store'],
#  '90259': ["Levi's",
#   'Converse',
#   'Gap',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Nordstrom'],
#  '90258': ['CB2', 'Container Store'],
#  '84114': ['Columbia',
#   'Betsey Johnson',
#   'Steve Madden',
#   'Guess',
#   'Ethan Allen',
#   'Windsor',
#   'Express',
#   'Crate & Barrel'],
#  '84113': ['Columbia', 'New Balance', 'Old Navy', 'Target'],
#  '80109': ['Crate & Barrel'],
#  '84111': ['Guess', 'Target', 'Nordstrom'],
#  '81763': ['Gap', 'Old Navy', 'Target', 'Home Depot'],
#  '81762': ['Nine West', '6pm.com'],
#  '90494': ['Melissa & Doug',
#   'Crocs',
#   'Old Navy',
#   '6pm.com',
#   'Target',
#   'Container Store'],
#  '81767': ['Puma',
#   'Melissa & Doug',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Target'],
#  '81766': ['J.Crew'],
#  '81989': ['Crocs', 'Old Navy', 'Target', 'Home Depot', 'Nordstrom'],
#  '81769': ['Columbia',
#   'KitchenAid',
#   'Betsey Johnson',
#   'Cuisinart',
#   'New Balance',
#   'Converse',
#   'BCBGMAXAZRIA',
#   'Guess',
#   "Kohl's",
#   'Target',
#   'Home Depot',
#   'Nordstrom'],
#  '91370': ['Melissa & Doug',
#   'KitchenAid',
#   'Cuisinart',
#   'Banana Republic',
#   'Gap',
#   'Restoration Hardware',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   '6pm.com',
#   'Target',
#   'Container Store'],
#  '81982': ['Converse', "Kohl's", 'Old Navy', 'Target', 'Home Depot'],
#  '90499': ['Converse',
#   'Banana Republic',
#   'Wet Seal',
#   'American Eagle',
#   'Express',
#   'Target',
#   'JC Penney',
#   'BUCKLE'],
#  '90079': ['Gap'],
#  '87374': ['KitchenAid', 'Banana Republic', 'Container Store', 'Shoebuy'],
#  '90071': ['Melissa & Doug',
#   'Crocs',
#   'Banana Republic',
#   'Gap',
#   'Life is good',
#   'Crate & Barrel',
#   'Target',
#   'Nordstrom',
#   'Shoebuy'],
#  '90070': ['Columbia',
#   'Nike',
#   'Coach',
#   'UGG Australia',
#   "Victoria's Secret",
#   'Wet Seal',
#   "Kohl's",
#   'Target',
#   'Lululemon',
#   'Nordstrom',
#   'Journeys'],
#  '85600': ["Levi's",
#   'Melissa & Doug',
#   'KitchenAid',
#   'Calvin Klein',
#   'DKNY',
#   "Kohl's",
#   'Nordstrom'],
#  '81965': ['Home Depot'],
#  '83863': ['Old Navy'],
#  '81966': ["Levi's",
#   'Tommy Hilfiger',
#   'Puma',
#   'Kenneth Cole',
#   'Calvin Klein',
#   'Lacoste',
#   'Converse',
#   'Diesel',
#   'Guess',
#   'Lenox',
#   'Banana Republic',
#   'Gap',
#   'Express',
#   "Kohl's",
#   'Crate & Barrel',
#   'Target',
#   'Home Depot',
#   'Nordstrom'],
#  '81961': ['Home Depot'],
#  '86827': ['Columbia',
#   'Converse',
#   'French Connection',
#   'Banana Republic',
#   'Kate Spade',
#   'Gap',
#   'J.Crew',
#   'Forever 21',
#   'Nordstrom'],
#  '81962': ['French Connection',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Diesel',
#   'Restoration Hardware',
#   'Express',
#   "Kohl's",
#   'Target',
#   'Nordstrom'],
#  '83869': ['KitchenAid',
#   'Converse',
#   'Nine West',
#   'Kate Spade',
#   'Gap',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '80364': ['Old Navy', 'Home Depot'],
#  '80367': ['Nordstrom'],
#  '80369': ['Le Creuset', "Kohl's", 'Target'],
#  '85046': ['Lacoste', 'Banana Republic', 'Target', 'Nordstrom'],
#  '80567': ['Gap', 'Last Call by Neiman Marcus', 'Old Navy', 'Container Store'],
#  '80564': ['Target'],
#  '80565': ['Banana Republic'],
#  '80562': ['Melissa & Doug',
#   'KitchenAid',
#   'Calvin Klein',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'Guess',
#   'Banana Republic',
#   'Gap',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Nordstrom'],
#  '90676': ['Columbia', 'Converse', 'Le Creuset'],
#  '80560': ['Nine West',
#   'Steve Madden',
#   'American Apparel',
#   'CB2',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Urban Outfitters'],
#  '80561': ['Le Creuset'],
#  '84063': ['Target'],
#  '85519': ['Columbia',
#   'Hanky Panky',
#   'Nine West',
#   'Gap',
#   'J.Crew',
#   'Target',
#   'Home Depot'],
#  '84067': ["Levi's",
#   'Puma',
#   'Calvin Klein',
#   'Lacoste',
#   'Banana Republic',
#   'Target',
#   'Home Depot'],
#  '84066': ['Tommy Hilfiger',
#   'Banana Republic',
#   'Gap',
#   'Express',
#   "Lands' End",
#   'Target'],
#  '80568': ['Steve Madden', 'Guess', 'Old Navy', 'Target', 'Nordstrom'],
#  '80569': ['Gap', 'Old Navy', 'Target'],
#  '84643': ["Levi's",
#   'Kenneth Cole',
#   'KitchenAid',
#   'Cuisinart',
#   'New Balance',
#   'Crocs',
#   'Guess',
#   'Banana Republic',
#   'Gap',
#   'Le Creuset',
#   'J.Crew',
#   "Lands' End",
#   'Old Navy',
#   'Crate & Barrel',
#   'CB2',
#   'Target',
#   'Container Store',
#   'Nordstrom'],
#  '86510': ['Melissa & Doug',
#   'Banana Republic',
#   'Gap',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Container Store'],
#  '86513': ['J.Crew'],
#  '84640': ["Levi's",
#   'Tommy Hilfiger',
#   'Puma',
#   'Kenneth Cole',
#   'KitchenAid',
#   'Calvin Klein',
#   'Cuisinart',
#   'New Balance',
#   'Converse',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'Ethan Allen',
#   'J.Crew',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Nordstrom'],
#  '90100': ['Hanky Panky', 'Horchow'],
#  '86517': ["Levi's",
#   'Tommy Hilfiger',
#   'Nicole Miller',
#   'Puma',
#   'Kenneth Cole',
#   'Calvin Klein',
#   'John Varvatos',
#   'Lacoste',
#   'New Balance',
#   'Converse',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Elie Tahari',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Kate Spade',
#   'Gap',
#   'J.Crew',
#   'Express',
#   '6pm.com',
#   'Nordstrom'],
#  '90102': ["Levi's",
#   'Columbia',
#   'Tommy Hilfiger',
#   'Nicole Miller',
#   'Hanky Panky',
#   'Puma',
#   'Kenneth Cole',
#   'KitchenAid',
#   'Calvin Klein',
#   'Betsey Johnson',
#   'John Varvatos',
#   'Lacoste',
#   'New Balance',
#   'Converse',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Crocs',
#   'Elie Tahari',
#   'Nine West',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Kate Spade',
#   'Gap',
#   'Life is good',
#   'Le Creuset',
#   'Ethan Allen',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   "Lands' End",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   '6pm.com',
#   'Target',
#   'Home Depot',
#   'Nordstrom',
#   'Shoebuy'],
#  '86518': ['J.Crew'],
#  '84648': ['Home Depot'],
#  '90109': ['Kenneth Cole',
#   'KitchenAid',
#   'Ethan Allen',
#   'Restoration Hardware',
#   "Kohl's",
#   "Lands' End",
#   'Home Depot'],
#  '90108': ['Betsey Johnson', 'Converse', 'Express'],
#  '83594': ['KitchenAid',
#   'John Varvatos',
#   'Guess',
#   'Banana Republic',
#   'Gap',
#   'Express',
#   'Old Navy',
#   'Home Depot'],
#  '80963': ['Columbia',
#   'Converse',
#   'Nine West',
#   'Life is good',
#   'Restoration Hardware',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Container Store',
#   'Home Depot'],
#  '80964': ['BCBGMAXAZRIA'],
#  '83268': ['Express'],
#  '80306': ['Crate & Barrel'],
#  '84245': ['Kenneth Cole',
#   'Steve Madden',
#   'Kate Spade',
#   'Crate & Barrel',
#   'Serena and Lily'],
#  '83918': ['Betsey Johnson',
#   'New Balance',
#   'Converse',
#   'Crocs',
#   'Steve Madden',
#   'Express',
#   'Target',
#   'Nordstrom'],
#  '84240': ['Target', 'Home Depot'],
#  '83260': ["Levi's", 'Converse', 'French Connection', 'Guess'],
#  '90724': ["Levi's", 'Express', 'Nordstrom'],
#  '83262': ['Gap', 'Old Navy'],
#  '83264': ['Crocs', 'Gap'],
#  '83913': ["Kohl's", "Lands' End", 'Old Navy', 'Crate & Barrel', 'Target'],
#  '83911': ['Nordstrom'],
#  '83469': ['Home Depot'],
#  '83466': ['KitchenAid', 'Cuisinart', 'Steve Madden'],
#  '83462': ['Kenneth Cole',
# ...
#   'Betsey Johnson',
#   'John Varvatos',
#   'Cuisinart',
#   'Lacoste',
#   'Villeroy & Boch',
#   'New Balance',
#   'Converse',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Crocs',
#   'Elie Tahari',
#   'Nine West',
#   'Steve Madden',
#   'Diesel',
#   'Nambe',
#   'Guess',
#   'Lenox',
#   'DKNY',
#   'Banana Republic',
#   'Kosta Boda',
#   'Mikasa',
#   'Kate Spade',
#   'Gap',
#   'Life is good',
#   'Le Creuset',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'Horchow',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   "Lands' End",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Crate & Barrel',
#   '6pm.com',
#   'CB2',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom',
#   'Serena and Lily',
#   'Shoebuy'],
#  '81169': ['Hanky Panky', 'Banana Republic', 'J.Crew', 'Nordstrom'],
#  '86395': ['Betsey Johnson', 'Old Navy', 'Target'],
#  '82542': ['Elie Tahari', 'Nine West', 'Old Navy', 'Crate & Barrel', 'Target'],
#  '82543': ['New Balance', 'Banana Republic', 'Old Navy'],
#  '82540': ['Melissa & Doug',
#   'KitchenAid',
#   'Cuisinart',
#   'New Balance',
#   'Banana Republic',
#   'Gap',
#   'Le Creuset',
#   'Restoration Hardware',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '82544': ['Tommy Hilfiger', 'Target'],
#  '89018': ["Kohl's", 'Target', 'Home Depot'],
#  '81384': ["Levi's",
#   'Kenneth Cole',
#   'Betsey Johnson',
#   'Steve Madden',
#   'Guess',
#   'Gap',
#   'Ethan Allen',
#   "Kohl's",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Serena and Lily',
#   'Shoebuy'],
#  '86949': ['Nicole Miller',
#   'Puma',
#   'Calvin Klein',
#   'Crocs',
#   'Banana Republic',
#   'Gap',
#   "Kohl's",
#   'Target'],
#  '81381': ["Lands' End"],
#  '90580': ['French Connection', 'Nine West', 'Kate Spade'],
#  '90583': ['Home Depot'],
#  '81389': ['Home Depot'],
#  '86868': ['Kenneth Cole',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Cuisinart',
#   'French Connection',
#   'Crocs',
#   'Steve Madden',
#   'Banana Republic',
#   'Gap',
#   'Life is good',
#   'Le Creuset',
#   'Restoration Hardware',
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Crate & Barrel',
#   '6pm.com',
#   'Target',
#   'Home Depot'],
#  '90587': ["Levi's",
#   'Columbia',
#   'Nicole Miller',
#   'KitchenAid',
#   'Calvin Klein',
#   'Cuisinart',
#   'BCBGMAXAZRIA',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Mikasa',
#   'Gap',
#   'Restoration Hardware',
#   'J.Crew',
#   'Express',
#   'Crate & Barrel',
#   'Container Store',
#   'Nordstrom'],
#  '90586': ['KitchenAid',
#   'Betsey Johnson',
#   'Cuisinart',
#   'Converse',
#   'Nine West',
#   'Steve Madden',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target'],
#  '80490': ['Lacoste'],
#  '80497': ['BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'Guess',
#   'Gap',
#   'Express',
#   'Old Navy',
#   'Target',
#   'Nordstrom',
#   'Shoebuy'],
#  '89403': ["Levi's",
#   'Calvin Klein',
#   'Lacoste',
#   'Converse',
#   'BCBGMAXAZRIA',
#   'Steve Madden',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Target'],
#  '80160': ['BCBGMAXAZRIA',
#   'Express',
#   "Kohl's",
#   'Crate & Barrel',
#   'Target',
#   'Nordstrom'],
#  '80161': ['Cuisinart', 'Gap', 'J.Crew', 'Container Store'],
#  '85447': ['Crocs', 'Guess'],
#  '80164': ['Wet Seal', 'Target'],
#  '90278': ["Levi's",
#   'Kenneth Cole',
#   'Melissa & Doug',
#   'Calvin Klein',
#   'Crocs',
#   'Banana Republic',
#   'Crate & Barrel',
#   'CB2',
#   'Target',
#   'Container Store'],
#  '90276': ['Nicole Miller',
#   'Cuisinart',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Steve Madden',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'J.Crew',
#   'Express',
#   'Crate & Barrel',
#   'Nordstrom'],
#  '90907': ['Kate Spade', 'Nordstrom'],
#  '80169': ['ZOO'],
#  '90273': ["Levi's",
#   'Columbia',
#   'Puma',
#   'Kenneth Cole',
#   'KitchenAid',
#   'Cuisinart',
#   'Converse',
#   'Diesel',
#   'DKNY',
#   'Gap',
#   'Life is good',
#   'Restoration Hardware',
#   "Kohl's",
#   'Last Call by Neiman Marcus',
#   'Crate & Barrel',
#   '6pm.com',
#   'Target',
#   'Home Depot',
#   'Nordstrom',
#   'Shoebuy'],
#  '90271': ["Levi's", 'Calvin Klein', 'Lacoste'],
#  '86447': ['John Varvatos',
#   'Le Creuset',
#   'Restoration Hardware',
#   'Nordstrom',
#   'Serena and Lily'],
#  '85697': ['Melissa & Doug',
#   'KitchenAid',
#   'Cuisinart',
#   'New Balance',
#   'Crocs',
#   'Nine West',
#   'Lenox',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'Life is good',
#   'Ethan Allen',
#   'Restoration Hardware',
#   "Kohl's",
#   "Lands' End",
#   'Pottery Barn',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '90478': ['Hanky Panky'],
#  '85286': ['Old Navy'],
#  '85288': ['KitchenAid', 'Gap', "Kohl's", 'Old Navy', 'Target'],
#  '85289': ['KitchenAid',
#   'Lacoste',
#   'Nine West',
#   'Gap',
#   'Le Creuset',
#   "Kohl's",
#   'Home Depot'],
#  '81703': ['Crocs', 'Gap', "Kohl's", 'Old Navy', 'Target'],
#  '81705': ['French Connection',
#   'Banana Republic',
#   'Gap',
#   'J.Crew',
#   'Old Navy',
#   '6pm.com',
#   'Target',
#   'Container Store'],
#  '81942': ['Banana Republic', 'J.Crew', 'Express'],
#  '90293': ['Kenneth Cole', 'Cuisinart', '6pm.com'],
#  '85662': ['KitchenAid',
#   'New Balance',
#   'Converse',
#   'Diesel',
#   'Banana Republic',
#   'Gap',
#   'Le Creuset',
#   'Restoration Hardware',
#   'J.Crew',
#   'Express',
#   'Old Navy',
#   'Crate & Barrel',
#   'Container Store'],
#  '86568': ['Banana Republic'],
#  '87352': ['Restoration Hardware'],
#  '85661': ['Steve Madden',
#   'Banana Republic',
#   'Restoration Hardware',
#   'J.Crew',
#   "Lands' End",
#   'Home Depot'],
#  '85664': ['Old Navy', 'Target'],
#  '83848': ["Levi's",
#   'KitchenAid',
#   'New Balance',
#   'Converse',
#   'Guess',
#   'DKNY',
#   'Gap',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Home Depot'],
#  '83849': ['Puma', 'Gap'],
#  '84393': ['Nine West', 'Express', "Kohl's", 'Target', 'Nordstrom'],
#  '84395': ['Express', 'Old Navy'],
#  '84397': ['KitchenAid',
#   'Betsey Johnson',
#   'Cuisinart',
#   'Converse',
#   'Nine West',
#   'Restoration Hardware',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '81944': ['Nine West'],
#  '83842': ['KitchenAid'],
#  '83843': ['Betsey Johnson',
#   'BCBGMAXAZRIA',
#   'Kate Spade',
#   'Restoration Hardware',
#   'Last Call by Neiman Marcus',
#   'Crate & Barrel',
#   'Target',
#   'Nordstrom'],
#  '83844': ["Levi's"],
#  '83845': ['Target'],
#  '84000': ['Le Creuset',
#   'Horchow',
#   'Old Navy',
#   'Container Store',
#   'Home Depot'],
#  '90114': ['Hanky Panky',
#   'KitchenAid',
#   'Banana Republic',
#   'Gap',
#   'J.Crew',
#   'Anthropologie',
#   'Crate & Barrel',
#   'Target',
#   'Nordstrom'],
#  '84005': ['Columbia',
#   'Puma',
#   'Last Call by Neiman Marcus',
#   'Crate & Barrel',
#   'Home Depot',
#   'Nordstrom'],
#  '80389': ['Ethan Allen', 'Crate & Barrel', '6pm.com', 'Container Store'],
#  '80384': ["Kohl's", 'Old Navy', 'Target', 'Home Depot'],
#  '80385': ['Tommy Hilfiger',
#   'Kenneth Cole',
#   'Calvin Klein',
#   'Lacoste',
#   'J.Crew',
#   'Express',
#   'Crate & Barrel',
#   'Target',
#   'Home Depot'],
#  '87227': ['John Varvatos',
#   'French Connection',
#   'Restoration Hardware',
#   'J.Crew',
#   "Lands' End",
#   'Crate & Barrel',
#   'CB2'],
#  '80383': ['Melissa & Doug',
#   'KitchenAid',
#   'BCBGMAXAZRIA',
#   'Express',
#   'Target'],
#  '81014': ["Levi's",
#   'Kenneth Cole',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Calvin Klein',
#   'Cuisinart',
#   'BCBGMAXAZRIA',
#   'Crocs',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Gap',
#   'Le Creuset',
#   'Restoration Hardware',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Nordstrom',
#   'Shoebuy'],
#  '81017': ['Puma',
#   'KitchenAid',
#   'Betsey Johnson',
#   'Crocs',
#   'Nine West',
#   'Steve Madden',
#   'Banana Republic',
#   'Gap',
#   'Express',
#   'Old Navy',
#   'Target',
#   'Container Store',
#   'Nordstrom'],
#  '81011': ['Lacoste', 'BCBGMAXAZRIA', 'Steve Madden', 'Express'],
#  '81010': ['Target'],
#  '81012': ['Banana Republic', 'Old Navy', 'Target'],
#  '83866': ['French Connection', 'BCBGMAXAZRIA', 'Banana Republic'],
#  '80545': ['Calvin Klein',
#   'New Balance',
#   'BCBGMAXAZRIA',
#   'Nike',
#   'Guess',
#   'Express',
#   "Kohl's",
#   'Charlotte Russe',
#   'Forever 21',
#   'H&M'],
#  '85066': ['KitchenAid',
#   'Betsey Johnson',
#   'Steve Madden',
#   'Ethan Allen',
#   'Express',
#   "Kohl's",
#   'Crate & Barrel',
#   'Target'],
#  '80015': ['Banana Republic', 'Gap', 'Target', 'Home Depot'],
#  '80540': ['Columbia',
#   'Nicole Miller',
#   'Hanky Panky',
#   'Calvin Klein',
#   'Betsey Johnson',
#   'BCBGMAXAZRIA',
#   'Elie Tahari',
#   'Nine West',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Kate Spade',
#   'J.Crew',
#   '6pm.com',
#   'Target'],
#  '85061': ["Kohl's", 'Target', 'Home Depot'],
#  '80010': ["Levi's",
#   'Puma',
#   'Cuisinart',
#   'Converse',
#   'DKNY',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   'Container Store',
#   'Nordstrom'],
#  '80011': ['Kenneth Cole',
#   'Calvin Klein',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'Banana Republic',
#   'Gap',
#   'Restoration Hardware',
#   'Crate & Barrel',
#   'Target',
#   'Nordstrom'],
#  '80940': ['Kenneth Cole',
#   'Steve Madden',
#   'Guess',
#   'Horchow',
#   'Express',
#   'CB2',
#   'Target',
#   'Container Store'],
#  '84628': ['KitchenAid',
#   'Banana Republic',
#   'Gap',
#   'J.Crew',
#   "Lands' End",
#   'Old Navy'],
#  '90121': ['Kate Spade',
#   'Gap',
#   'J.Crew',
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Target',
#   'Nordstrom'],
#  '80943': ['BCBGMAXAZRIA'],
#  '90126': ['Guess'],
#  '80946': ["Levi's",
#   'KitchenAid',
#   'Betsey Johnson',
#   'Cuisinart',
#   'New Balance',
#   'Converse',
#   'Elie Tahari',
#   'Nine West',
#   'Life is good',
#   'Le Creuset',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'J.Crew',
#   "Kohl's",
#   "Lands' End",
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Home Depot',
#   'Nordstrom'],
#  '80947': ["Kohl's", 'Target', 'Home Depot'],
#  '80948': ['Nine West', 'Restoration Hardware', 'Home Depot'],
#  '80949': ["Levi's",
#   'J.Crew',
#   "Kohl's",
#   'Crate & Barrel',
#   'Target',
#   'Container Store'],
#  '86535': ["Levi's",
#   'Puma',
#   'New Balance',
#   'Express',
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Shoebuy'],
#  '90128': ['Diesel', 'Banana Republic'],
#  '84627': ["Levi's",
#   'KitchenAid',
#   'Cuisinart',
#   'Ralph Lauren',
#   'Le Creuset',
#   "Kohl's"],
#  '86530': ['KitchenAid',
#   'Cuisinart',
#   "Kohl's",
#   'Old Navy',
#   '6pm.com',
#   'Target'],
#  '83934': ['Converse',
#   'BCBGMAXAZRIA',
#   'Steve Madden',
#   'Gap',
#   'J.Crew',
#   'Express',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Nordstrom'],
#  '91580': ["Levi's", 'Kenneth Cole', "Kohl's", 'Old Navy', 'Target'],
#  '83932': ["Levi's", "Kohl's", 'Old Navy', 'Shoebuy'],
#  '83933': ['KitchenAid',
#   'Cuisinart',
#   'Nine West',
#   'Le Creuset',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   "Lands' End",
#   '6pm.com',
#   'Target',
#   'Home Depot'],
#  '89795': ['Columbia', 'Cuisinart', 'New Balance', 'Crate & Barrel'],
#  '83938': ['Villeroy & Boch'],
#  '87289': ['Target'],
#  '88817': ['Kenneth Cole',
#   'Calvin Klein',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Hard Tail',
#   'Diesel',
#   'DKNY'],
#  '90642': ['Target'],
#  '87280': ['Gap', "Kohl's", 'Target'],
#  '91431': ['Target'],
#  '83448': ['Home Depot'],
#  '87287': ["Levi's",
#   'Tommy Hilfiger',
#   'Nicole Miller',
#   'KitchenAid',
#   'John Varvatos',
#   'Cuisinart',
#   'Lacoste',
#   'Villeroy & Boch',
#   'New Balance',
#   'Converse',
#   'Elie Tahari',
#   'Diesel',
#   'DKNY',
#   'Mikasa',
#   'Gap',
#   'Le Creuset',
#   'Restoration Hardware',
#   'J.Crew',
#   'Crate & Barrel',
#   'CB2',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Nordstrom'],
#  '87284': ['BCBGMAXAZRIA', 'Banana Republic'],
#  '89682': ['Kenneth Cole', 'John Varvatos'],
#  '90056': ['Gap', 'Le Creuset', 'Home Depot'],
#  '90721': ['KitchenAid',
#   'Betsey Johnson',
#   'Cuisinart',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Guess'],
#  '90052': ['Puma',
#   'Kenneth Cole',
#   'Melissa & Doug',
#   'KitchenAid',
#   'Calvin Klein',
#   'Cuisinart',
#   'Lacoste',
#   'Villeroy & Boch',
#   'French Connection',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Kosta Boda',
#   'Kate Spade',
#   'Gap',
#   'Life is good',
#   'Le Creuset',
#   'Ethan Allen',
#   'Restoration Hardware',
#   'J.Crew',
#   'Express',
#   "Kohl's",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Home Depot',
#   'Serena and Lily'],
#  '90723': ['Melissa & Doug', 'KitchenAid', 'Cuisinart'],
#  '84714': ['Restoration Hardware'],
#  '84717': ['Banana Republic', "Kohl's"],
#  '86231': ["Levi's",
#   'Betsey Johnson',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'Banana Republic',
#   'Express',
#   "Kohl's",
#   'Old Navy',
#   '6pm.com',
#   'CB2',
#   'Target',
#   'Nordstrom'],
#  '84710': ["Kohl's"],
#  '84536': ['Nordstrom'],
#  '84530': ['KitchenAid',
#   'New Balance',
#   'Converse',
#   'DKNY',
#   "Kohl's",
#   'Old Navy',
#   'Home Depot',
#   'Torrid'],
#  '84533': ['Home Depot'],
#  '84539': ["Levi's",
#   'Kenneth Cole',
#   'New Balance',
#   'Crocs',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Shoebuy'],
#  '86319': ['Nordstrom'],
#  '87130': ["Levi's", 'KitchenAid', 'Le Creuset', 'Home Depot'],
#  '89499': ['Container Store'],
#  '80838': ['KitchenAid',
#   'Kate Spade',
#   'Le Creuset',
#   'Ethan Allen',
#   'Crate & Barrel',
#   'Home Depot',
#   'Nordstrom'],
#  '91051': ['Lacoste',
#   'New Balance',
#   'Banana Republic',
#   "Kohl's",
#   "Lands' End",
#   'Crate & Barrel',
#   'Target',
#   'Nordstrom'],
#  '86401': ['Steve Madden', 'Diesel', 'Target'],
#  '80837': ['Villeroy & Boch',
#   'French Connection',
#   'Restoration Hardware',
#   'Horchow',
#   'Crate & Barrel',
#   'Container Store',
#   'Home Depot'],
#  '91054': ['Old Navy', 'Crate & Barrel', 'Target', 'Home Depot'],
#  '86406': ['Betsey Johnson',
#   'New Balance',
#   'Converse',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'Kate Spade',
#   'Express',
#   'Old Navy',
#   '6pm.com',
#   'Target',
#   'Nordstrom'],
#  '80832': ["Levi's",
#   'Kenneth Cole',
#   'KitchenAid',
#   'Cuisinart',
#   'Converse',
#   'Steve Madden',
#   'Banana Republic'],
#  '89716': ['Kenneth Cole',
#   'BCBGMAXAZRIA',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Express',
#   'Target',
#   'Nordstrom'],
#  '90684': ["Levi's", 'Converse', 'Gap', "Kohl's", 'Old Navy', 'Target'],
#  '91045': ['Guess'],
#  '83154': ['Columbia',
#   'John Varvatos',
#   'Crocs',
#   'Banana Republic',
#   'Gap',
#   'Life is good',
#   "Kohl's",
#   'Old Navy',
#   'Target',
#   'Home Depot',
#   'Shoebuy'],
#  '85361': ['Target'],
#  '86715': ['KitchenAid', 'Cuisinart', "Kohl's", 'Target', 'Home Depot'],
#  '85849': ["Levi's"],
#  '85842': ['KitchenAid',
#   'Cuisinart',
#   'Nine West',
#   'Steve Madden',
#   'Kate Spade',
#   'Gap',
#   "Kohl's",
#   'Old Navy',
#   'Crate & Barrel',
#   'CB2',
#   'Target',
#   'Nordstrom'],
#  '85841': ['Elie Tahari',
#   'DKNY',
#   'Kate Spade',
#   'J.Crew',
#   'Last Call by Neiman Marcus',
#   'Crate & Barrel',
#   'Home Depot',
#   'Nordstrom',
#   'Shoebuy'],
#  '91454': ['KitchenAid', 'Old Navy', 'Target'],
#  '91455': ['J.Crew', 'Express', 'Last Call by Neiman Marcus', 'Shoebuy'],
#  '90689': ['KitchenAid',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Kate Spade',
#   'Life is good',
#   'Crate & Barrel',
#   '6pm.com',
#   'Target',
#   'Shoebuy'],
#  '87628': ['J.Crew', 'Target'],
#  '91451': ['Gap', 'Express', "Kohl's", 'Old Navy', 'Target', 'Home Depot'],
#  '91452': ['Old Navy'],
#  '90601': ["Levi's",
#   'Columbia',
#   'Nicole Miller',
#   'Kenneth Cole',
#   'Melissa & Doug',
#   'Calvin Klein',
#   'Lacoste',
#   'New Balance',
#   'French Connection',
#   'BCBGMAXAZRIA',
#   'Nine West',
#   'Steve Madden',
#   'Diesel',
#   'Guess',
#   'DKNY',
#   'Banana Republic',
#   'Kate Spade',
#   'Gap',
#   'Ethan Allen',
#   'Express',
#   "Kohl's",
#   'Last Call by Neiman Marcus',
#   'Crate & Barrel',
#   '6pm.com',
#   'CB2',
#   'Target',
#   'Container Store',
#   'Nordstrom',
#   'Shoebuy'],
#  '91078': ["Kohl's", 'Target'],
#  '87626': ['Target'],
#  '87627': ['Columbia',
#   'Kenneth Cole',
#   'KitchenAid',
#   'Cuisinart',
#   'New Balance',
#   'Crocs',
#   'Nine West',
#   'Kate Spade',
#   'Life is good',
#   'Le Creuset',
#   'Restoration Hardware',
#   'J.Crew',
#   "Kohl's",
#   "Lands' End",
#   'Last Call by Neiman Marcus',
#   'Old Navy',
#   'Crate & Barrel',
#   'Target',
#   'Container Store',
#   'Nordstrom'],
#  '91458': ['KitchenAid',
#   'Guess',
#   'Gap',
#   "Kohl's",
#   'Target',
#   'Container Store',
#   'Home Depot'],
#  '85360': ['Gap'],
#  ...}

# %%
# try it out. User 83065 likes Kohl's and Target
brandsfor['83065']
# Out:
# ["Kohl's", 'Target']

# %%
# User 82983 likes more
brandsfor['82983']
# Out:
# ['Hanky Panky',
#  'Betsey Johnson',
#  'Converse',
#  'Steve Madden',
#  'Old Navy',
#  'Target',
#  'Nordstrom']

# %% [markdown]
# ## 2. Jaccard Similarity ##
#
# The Jaccard Similarity allows us to compare two sets
# If we regard people as merely being a set of brands they prefer
# the Jaccard Similarity allows us to compare people
#
# Example. the jaccard similarty between user 82983 and 83065 is .125
#             because
#
#             brandsfor['83065'] == ["Kohl's", 'Target']
#
#             brandsfor['82983'] == ['Hanky Panky', 'Betsey Johnson', 'Converse', 'Steve Madden', 'Old Navy', 'Target', 'Nordstrom']
#
# the intersection of these two sets is just set("Target")
# the union of the two sets is set(['Target', 'Hanky Panky', 'Betsey Johnson', 'Converse', 'Steve Madden', 'Old Navy', 'Target', 'Nordstrom'])
# so the len(intersection) / len(union) = 1 / 8 == .125
#
#
# EXERCISE: what is the Jaccard Similarity
#           between user 82956 and user 82963?

# %%
brandsfor['82956'] # ['Diesel', 'Old Navy', 'Crate & Barrel', 'Target']
brandsfor['82963'] # ['Puma', 'New Balance', 'Old Navy', 'Target']
# Out:
# ['Puma', 'New Balance', 'Old Navy', 'Target']

# %%
'''
EXERCISE: Complete the jaccard method below.
          It should take in a list of brands, and output the 
          jaccard similarity between them

This should work with anything in the set, for example
jaccard([1,2,3], [2,3,4,5,6])  == .3333333

HINT: set1 & set2 is the intersection
      set1 | set2 is the union

'''

def jaccard(first, second):
  first = set(first)
  second = set(second)
  return float(len(first & second)) / len(first | second)

jaccard(brandsfor['82956'], brandsfor['82963'])
# Out:
# 0.3333333333333333

# %%
# try it out!
print(brandsfor['83065']) # brands for user 83065
print(brandsfor['82983']) # brands for user 82983
jaccard(brandsfor['83065'], brandsfor['82983'])
# Out:
# ["Kohl's", 'Target']
# ['Hanky Panky', 'Betsey Johnson', 'Converse', 'Steve Madden', 'Old Navy', 'Target', 'Nordstrom']
# 0.125

# %%
jaccard(brandsfor['82956'], brandsfor['82963'])
# Out:
# 0.3333333333333333

# %% [markdown]
# ## 3. Recommender (User Similarity)
#
# Our recommender will be a modified KNN collaborative algorithm.
# Input: A given user's brands that they like
# Output: A set (no repeats) of brand recommendations based on
#         similar users preferences
#
# 1. When a user's brands are given to us, we will calculate the input user's
# jaccard similarity with every person in our brandsfor dictionary
#
# 2. We will pick the K most similar users and recommend
# the brands that they like that the given user doesn't know about
#
# EXAMPLE:
# Given User likes ['Target', 'Old Navy', 'Banana Republic', 'H&M']
# Outputs: ['Forever 21', 'Gap', 'Steve Madden']

# %%
given_user = ['Target', 'Old Navy', 'Banana Republic', 'H&M']

#similarty between user 83065 and given user
brandsfor['83065'] # ["Kohl's", 'Target']
jaccard(brandsfor['83065'], given_user) # 0.2
# Out:
# 0.2

# %% [markdown]
# #### EXERCISE:
#
# Find the similarty between given_user and ALL of our users
# output should be a dictionary where
# the key is a user id and the value is the jaccard similarity
#
#
#
# {...
#  '83055': 0.25,
#  '83056': 0.0,
#  '83058': 0.1111111111111111,
#  '83060': 0.07894736842105263,
#  '83061': 0.4,
#  '83064': 0.25,
#  '83065': 0.2,
#  ...}

# %%
similarities = {k: jaccard(given_user, v) for k, v in brandsfor.iteritems()}

similarities

#K = 5 #number of similar users to look at
# Out:
# {'80050': 0.10526315789473684,
#  '81402': 0.3333333333333333,
#  '84916': 0.0,
#  '86360': 0.2222222222222222,
#  '84914': 0.125,
#  '84913': 0.0,
#  '86367': 0.16666666666666666,
#  '89376': 0.2,
#  '86365': 0.18181818181818182,
#  '89378': 0.0,
#  '88710': 0.1111111111111111,
#  '86369': 0.0,
#  '84919': 0.2857142857142857,
#  '89176': 0.2,
#  '89173': 0.06818181818181818,
#  '89170': 0.0,
#  '89171': 0.0,
#  '82198': 0.06666666666666667,
#  '89482': 0.09375,
#  '85460': 0.0,
#  '89480': 0.4,
#  '80637': 0.16666666666666666,
#  '85599': 0.2,
#  '89489': 0.0,
#  ...}

# %%
# Now for the top K most similar users, let's aggregate the brands they like.
# I sort by the jaccard similarty so most similar users are first
# I use the sorted method, but because I'm sorting dictionaries
# I specify the "key" as the value of the dictionary
# the key is what the list should sort on
# so the most similar users end up being on top
most_similar_users = sorted(similarities, key=similarities.get, reverse=True)[:K] # ['81012', '84807', '88549', '82970', '91362']
#most_similar_users

# %%
# list of K similar users' IDs
most_similar_users
# Out:
# ['81012', '84807', '88549', '82970', '91362']

# %%
# let's see what some of the most similar users likes
print(brandsfor[most_similar_users[0]])
print(brandsfor[most_similar_users[1]])
print(brandsfor[most_similar_users[2]])
print(brandsfor[most_similar_users[3]])
print(brandsfor[most_similar_users[4]])
# Out:
# ['Banana Republic', 'Old Navy', 'Target']
# ['Steve Madden', 'Banana Republic', 'Old Navy', 'Target']
# ['Banana Republic', 'Old Navy', 'Forever 21', 'Target']
# ['Banana Republic', 'Gap', 'Old Navy', 'Target']
# ['Banana Republic', 'Gap', 'Old Navy', 'Target']

# %%
# Aggregate all brands liked by the K most similar users into a single set
brands_to_recommend = set()
for user in most_similar_users:
    # for each user
    brands_to_recommend.update(set(brandsfor[user]))
    # add to the set of brands_to_recommend
    
brands_to_recommend
# Out:
# {'Banana Republic', 'Forever 21', 'Gap', 'Old Navy', 'Steve Madden', 'Target'}

# %%
# EXERCISE: use a set difference so brands_to_recommend only has
# brands that given_user hasn't seen yet
brands_to_recommend = brands_to_recommend - set(given_user)
brands_to_recommend
# Out:
# {'Forever 21', 'Gap', 'Steve Madden'}

# %%
import collections

# We can take this one step further and calculate a "score" of recommendation
# We will define the score as being the number of times
# a brand appears within the first K users
brands_to_recommend = []
for user in most_similar_users:
    brands_to_recommend += list(set(brandsfor[user]) - set(given_user))

# Use a counter to count the number of times a brand appears
recommend_with_scores = collections.Counter(brands_to_recommend)

# Now we see Gap has the highest score!
recommend_with_scores
# Out:
# Counter({'Forever 21': 1, 'Gap': 2, 'Steve Madden': 1})

# %% [markdown]
# ## 4. Recommender (Item Similarity)

# %%
'''
We can also define a similary between items using jaccard similarity.
We can say that the similarity between two items is the jaccard similarity
between the sets of people who like the two brands.

Example: similarity of Gap to Target is:
'''

# %%
# filter users by liking Gap
gap_lovers = set(user_brands['Gap' == user_brands.Store].ID)
#gap_lovers
old_navy_lovers = set(user_brands['Old Navy' == user_brands.Store].ID)
#old_navy_lovers

# %%
# similarty between Gap and Old Navy
jaccard(gap_lovers, old_navy_lovers)
# Out:
# 0.35437212360289283

# %%
guess_lovers = set(user_brands['Guess' == user_brands.Store].ID)
# similarty between Gap andGuess
jaccard(guess_lovers, gap_lovers)
# Out:
# 0.21257750221434898

# %%
calvin_lovers = set(user_brands['Calvin Klein' == user_brands.Store].ID)
# similarty between Gap and Calvin Klein
jaccard(calvin_lovers, gap_lovers)
# Out:
# 0.2068654019873532
