# %% [markdown]
# # Introduction to Linear Regression

# %% [markdown]
# Regression is the process of learning a mapping from a vector of input data to a quantitative output given a set of observations. For example, coordinates in a room to Wi-Fi signal strength, someone's Body Mass Index to their life expectancy or a stock's performance over the last 5 days to it's value tomorrow.
#
# There are numerous methods for addressing this problem, each with their own set of assumptions and behaviour. Some are ideal for tackling large volumes of data while others provide more informative probabilistic outputs.
#
# In this lab, we'll focus on Linear Regression; a good point of reference for many other regression techniques and still used widely around the world today due to their simplicity and favourable scaling characteristics.

# %% [markdown]
# We will be using [statsmodels](http://statsmodels.sourceforge.net/devel/examples/notebooks/generated/ols.html) for learning about linear regression. It covers the models better than in scikit when we are learning and want more insights into the model parameters. But we will mainly be using scikit learn for the rest of the course.

# %%
# Import the libraries required
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %%
# Read in data
house_data = pd.read_csv("chicagohouseprices2.csv", index_col=0)

# %%
#  Find header values of the data
house_data.head()
# Out:
#                               Address Neighborhood          HouseType   Price  \
# 0   2111 W Division St #5, Chicago IL  Wicker Park              Condo  390000
# 1     1520 W Walton St #2, Chicago IL  Wicker Park              Condo  320500
# 2        2047 W Thomas St, Chicago IL  Wicker Park  Multi-Family Home  620000
# 3  1735 N Paulina St #314, Chicago IL  Wicker Park              Condo  318000
# 4        1634 W Beach Ave, Chicago IL  Wicker Park  Multi-Family Home  477000
#
#    Bath  CrimeIndex  MinutesToLoop  MilesToLake  Age  LotSizeSqft  \
# 0   NaN        2.59              9         3.91    0            0
# 1   NaN        4.10              7         3.02    0            0
# 2   4.0        2.09              9         3.84   94         3049
# 3   NaN        2.40              9         2.90    0            0
# 4   2.0        4.63              9         2.96   31         2614
#
#    HouseSizeSqft  SchoolIndex  EstimatedPrice
# 0              0         36.2        335790.0
# 1              0         91.7        376908.0
# 2           3492         36.2        629300.0
# 3              0         50.0        297330.0
# 4           1840         78.9        463644.0

# %%
# Summarise the data

house_data.describe()
# Out:
#               Price       Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# count  2.190000e+02  70.000000  219.000000     219.000000   219.000000
# mean   4.834311e+05   2.271429    4.663607       9.698630     3.420411
# std    4.001249e+05   0.883364    1.418146       2.898995     0.352522
# min    2.450000e+04   1.000000    1.090000       6.000000     2.770000
# 25%    3.190000e+05   2.000000    3.940000       8.000000     3.150000
# 50%    3.900000e+05   2.000000    4.930000       9.000000     3.400000
# 75%    5.125000e+05   3.000000    5.580000      10.000000     3.685000
# max    3.686000e+06   4.000000    8.080000      22.000000     4.200000
#
#               Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  EstimatedPrice
# count  219.000000   219.000000     219.000000   219.000000    2.190000e+02
# mean    29.424658   873.200913     699.977169    49.197717    4.862191e+05
# std     49.155880  1392.893683    1175.278922    18.554525    3.978582e+05
# min      0.000000     0.000000       0.000000    16.700000    2.883650e+04
# 25%      0.000000     0.000000       0.000000    36.100000    3.074488e+05
# 50%      0.000000     0.000000       0.000000    50.000000    3.919800e+05
# 75%     41.000000  2614.000000    1344.000000    59.500000    5.324750e+05
# max    131.000000  7405.000000    6422.000000    93.900000    3.973508e+06

# %%
# Look for any linear correlations in the data
house_data.corr()
# Out:
#                    Price      Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# Price           1.000000  0.113943    0.118667      -0.034644    -0.072433
# Bath            0.113943  1.000000    0.163785       0.166330    -0.157517
# CrimeIndex      0.118667  0.163785    1.000000       0.194745     0.102382
# MinutesToLoop  -0.034644  0.166330    0.194745       1.000000     0.374829
# MilesToLake    -0.072433 -0.157517    0.102382       0.374829     1.000000
# Age             0.237720 -0.039220   -0.036644      -0.023820    -0.047087
# LotSizeSqft     0.443341 -0.029979   -0.008807      -0.053292     0.006240
# HouseSizeSqft   0.456272  0.698526    0.070952      -0.032437    -0.046517
# SchoolIndex    -0.072403 -0.047992   -0.100256      -0.196728    -0.205966
# EstimatedPrice  0.983784  0.105632    0.122793      -0.034185    -0.082604
#
#                      Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  \
# Price           0.237720     0.443341       0.456272    -0.072403
# Bath           -0.039220    -0.029979       0.698526    -0.047992
# CrimeIndex     -0.036644    -0.008807       0.070952    -0.100256
# MinutesToLoop  -0.023820    -0.053292      -0.032437    -0.196728
# MilesToLake    -0.047087     0.006240      -0.046517    -0.205966
# Age             1.000000     0.716774       0.645147    -0.029953
# LotSizeSqft     0.716774     1.000000       0.828598    -0.055458
# HouseSizeSqft   0.645147     0.828598       1.000000    -0.023378
# SchoolIndex    -0.029953    -0.055458      -0.023378     1.000000
# EstimatedPrice  0.255628     0.454939       0.471783    -0.073825
#
#                 EstimatedPrice
# Price                 0.983784
# Bath                  0.105632
# CrimeIndex            0.122793
# MinutesToLoop        -0.034185
# MilesToLake          -0.082604
# Age                   0.255628
# LotSizeSqft           0.454939
# HouseSizeSqft         0.471783
# SchoolIndex          -0.073825
# EstimatedPrice        1.000000

# %%
# Plot the data
pd.scatter_matrix(house_data, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11649b610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11654c6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116502d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116841e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1168d2050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116a32350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116ab37d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116b1a090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116b9b510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116d1d390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x116d59c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116ddca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116e41850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116ec37d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116efb810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116fb5590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117038410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11709c6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117120550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117187250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117210350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1172941d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1172f5c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117378a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1173dead0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11745ea50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11746ded0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117650810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1176d4690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117737950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1177bc7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1179234d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1179ac5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a30450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a93e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117b16d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116d2a1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117beb950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d707d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ddd310>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117f63190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117fc61d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11884a150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118880190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11892ded0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1189b1d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a24050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a9ae90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b01b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b89c90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118c0db10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118c7d590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118f03410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118f67450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118fe93d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119822410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1198da190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119950fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1199c32d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119a47150>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x119aa2e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119c2cf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119caed90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119d07810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119d8cf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119dfd390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119e7e810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119eb8950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a071390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a0f4210>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a159150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a1cdf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a237c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a2c0d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a343c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a3b3690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a637510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a69b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a71f4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a757510>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a912290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a995110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a9fa3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11aa7d250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11aad7f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ab6d050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11abe5e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ad54910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11add8790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119cd4510>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11ae9de50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11af23890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11af9c290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b01f7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b083550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b1054d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b09dd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b1f6550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b37b3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b3dd9d0>]], dtype=object)

# %% [markdown]
# ### Questions?
#
# - Can you describe the data set - give a summary of what's happening?
# - What looks to be affecting house prices from our initial inspection?
# - What is the type of relationship in those variables affecting price?

# %%
# create a fitted model in one line (OLS)
lm = smf.ols(formula='Price ~ Bath + HouseSizeSqft', data=house_data).fit()

# print the coefficients
lm.params
# Out:
# Intercept        508310.776747
# Bath             -28995.658012
# HouseSizeSqft       133.011874
# dtype: float64

# %%
# What would you expect a house price to be for a house with 3 bathrooms and 350 sqft?
# Calculate it.
508310 -28995.66*3 + 133*350
# Out:
# 467873.02

# %%
# Create a pandas DataFrame from this data.

House_new = pd.DataFrame({'EstimatedPrice': [house_data.Bath, house_data.HouseSizeSqft,house_data.LotSizeSqft]})
House_new.head()
# Out:
#                                       EstimatedPrice
# 0  0      NaN
# 1      NaN
# 2      4.0
# 3      NaN
# 4 ...
# 1  0         0
# 1         0
# 2      3492
# 3         ...
# 2  0         0
# 1         0
# 2      3049
# 3         ...

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.340
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):              0.269
# Time:                        20:54:33   Log-Likelihood:                -1030.2
# No. Observations:                  70   AIC:                             2066.
# Df Residuals:                      67   BIC:                             2073.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept      5.083e+05   2.05e+05      2.478      0.016      9.89e+04  9.18e+05
# Bath            -2.9e+04   1.16e+05     -0.250      0.803     -2.61e+05  2.03e+05
# HouseSizeSqft   133.0119     99.854      1.332      0.187       -66.297   332.321
# ==============================================================================
# Omnibus:                       85.337   Durbin-Watson:                   1.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              891.863
# Skew:                           3.754   Prob(JB):                    2.16e-194
# Kurtosis:                      18.793   Cond. No.                     7.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Let's try just the estimated price
# create a fitted model in one line
lm = smf.ols(formula='Price ~ EstimatedPrice ', data=house_data).fit()

# print the coefficients
lm.params
# Out:
# Intercept         2371.037940
# EstimatedPrice       0.989389
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     6529.
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):          6.25e-164
# Time:                        20:15:37   Log-Likelihood:                -2758.9
# No. Observations:                 219   AIC:                             5522.
# Df Residuals:                     217   BIC:                             5529.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept       2371.0379   7685.764      0.308      0.758     -1.28e+04  1.75e+04
# EstimatedPrice     0.9894      0.012     80.801      0.000         0.965     1.014
# ==============================================================================
# Omnibus:                      198.218   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8006.566
# Skew:                           3.156   Prob(JB):                         0.00
# Kurtosis:                      31.941   Cond. No.                     9.93e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# create a DataFrame with the minimum and maximum values of EstimatedPrice
X_new = pd.DataFrame({'EstimatedPrice': [house_data.EstimatedPrice.min(), house_data.EstimatedPrice.max()]})
X_new.head()
# Out:
#    EstimatedPrice
# 0         28836.5
# 1       3973508.0

# %%
preds = lm.predict(X_new)
preds
# Out:
# array([   30901.56354902,  3933717.48261279])

# %%
# first, plot the observed data
house_data.plot(kind='scatter', x='EstimatedPrice', y='Price')

# then, plot the least squares line
plt.plot(X_new, preds, c='red', linewidth=2)

# %%
# Try selecting different variables or combinations of variables. Can you get a better fit?

# %% [markdown]
# ## Themepark

# %% [markdown]
# The file themepark.csv has some data from a theme park. Children were asked to rate their experience on a scale
# from 0-5. This data was compared against the number of hours they spent in the park.

# %%
# Create a pandas DataFrame from this data.
X_new = pd.DataFrame({'EstimatedPrice': [house_data.EstimatedPrice.min(), house_data.EstimatedPrice.max()]})
X_new.head()

# %%
# Have a look at the data (e.g. display the head or tail, use describe, etc.)

# %%
# Draw a scatterplot of this data.

# %%
# Try doing a linear regression on this data

# %%
# Plot this regression over the top of the data. Could the regression be better?
